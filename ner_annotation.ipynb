# %%
import os
import json
from spacy.tokens import Span
import spacy
from spacy.util import filter_spans
from spacy.tokens import DocBin
from tqdm import tqdm
import os
import random
def pre_regex_annotation(doc):
    nlp = spacy.blank("de")
    ruler = nlp.add_pipe("entity_ruler", config={"overwrite_ents": True})
    patterns_baugebiete = [
        {"label":"BAUGEBIETE","pattern":[{"TEXT":{"FUZZY":"kleinsiedlungsgebiet"}}]},
        {"label":"BAUGEBIETE","pattern":[{"TEXT":{"FUZZY":"kleinsiedlungsgebiete"}}]},
        {"label":"BAUGEBIETE","pattern":[{'IS_UPPER': True, 'LENGTH': 2, 'LOWER': 'ws'}]},
        {"label":"BAUGEBIETE","pattern": [{"TEXT": {"REGEX": "^WS($|[^0-9])"}}]},
        {"label":"BAUGEBIETE","pattern":[{'LOWER': 'ws', 'IS_UPPER': True, 'LENGTH': 2},{'IS_DIGIT': True, 'LENGTH': 1, 'LOWER': '1'}]},
        {"label":"BAUGEBIETE","pattern":[{'LOWER': 'ws', 'IS_UPPER': True, 'LENGTH': 2},{'IS_DIGIT': True, 'LENGTH': 1, 'LOWER': '2'}]},
        {"label":"BAUGEBIETE","pattern":[{'LOWER': 'ws', 'IS_UPPER': True, 'LENGTH': 2},{'IS_DIGIT': True, 'LENGTH': 1, 'LOWER': '3'}]},
        {"label":"BAUGEBIETE","pattern":[{'LOWER': 'ws', 'IS_UPPER': True, 'LENGTH': 2},{'IS_DIGIT': True, 'LENGTH': 1, 'LOWER': '4'}]},
        {"label":"BAUGEBIETE","pattern":[{'LOWER': 'ws', 'IS_UPPER': True, 'LENGTH': 2},{'IS_DIGIT': True, 'LENGTH': 1, 'LOWER': '5'}]},
        {"label":"BAUGEBIETE","pattern":[{'LOWER': 'ws', 'IS_UPPER': True, 'LENGTH': 2},{'IS_DIGIT': True, 'LENGTH': 1, 'LOWER': '6'}]},
        {"label":"BAUGEBIETE","pattern":[{'LOWER': 'ws', 'IS_UPPER': True, 'LENGTH': 2},{'IS_DIGIT': True, 'LENGTH': 1, 'LOWER': '7'}]},
        {"label":"BAUGEBIETE","pattern":[{'LOWER': 'ws1', 'IS_UPPER': True, 'LENGTH': 3}]},
        {"label":"BAUGEBIETE","pattern":[{'LOWER': 'ws2', 'IS_UPPER': True, 'LENGTH': 3}]},
        {"label":"BAUGEBIETE","pattern":[{'LOWER': 'ws3', 'IS_UPPER': True, 'LENGTH': 3}]},
        {"label":"BAUGEBIETE","pattern":[{'LOWER': 'ws4', 'IS_UPPER': True, 'LENGTH': 3}]},
        {"label":"BAUGEBIETE","pattern":[{'LOWER': 'ws5', 'IS_UPPER': True, 'LENGTH': 3}]},
        {"label":"BAUGEBIETE","pattern":[{'LOWER': 'ws6', 'IS_UPPER': True, 'LENGTH': 3}]},
        {"label":"BAUGEBIETE","pattern":[{'LOWER': 'ws7', 'IS_UPPER': True, 'LENGTH': 3}]},
        {"label":"BAUGEBIETE","pattern":[{"TEXT":{"FUZZY":"reines"}},{"TEXT":{"FUZZY":"wohngebiet"}}]},
        {"label":"BAUGEBIETE","pattern":[{"TEXT":{"FUZZY":"reine"}},{"TEXT":{"FUZZY":"wohngebiete"}}]},
        {"label":"BAUGEBIETE","pattern":[{'IS_UPPER': True, 'LENGTH': 2, 'LOWER': 'wr'}]},
        {"label":"BAUGEBIETE","pattern": [{"TEXT": {"REGEX": "^WR($|[^0-9])"}}]},
        {"label":"BAUGEBIETE","pattern":[{'LOWER': 'wr', 'IS_UPPER': True, 'LENGTH': 2},{'IS_DIGIT': True, 'LENGTH': 1, 'LOWER': '1'}]},
        {"label":"BAUGEBIETE","pattern":[{'LOWER': 'wr', 'IS_UPPER': True, 'LENGTH': 2},{'IS_DIGIT': True, 'LENGTH': 1, 'LOWER': '2'}]},
        {"label":"BAUGEBIETE","pattern":[{'LOWER': 'wr', 'IS_UPPER': True, 'LENGTH': 2},{'IS_DIGIT': True, 'LENGTH': 1, 'LOWER': '3'}]},
        {"label":"BAUGEBIETE","pattern":[{'LOWER': 'wr', 'IS_UPPER': True, 'LENGTH': 2},{'IS_DIGIT': True, 'LENGTH': 1, 'LOWER': '4'}]},
        {"label":"BAUGEBIETE","pattern":[{'LOWER': 'wr', 'IS_UPPER': True, 'LENGTH': 2},{'IS_DIGIT': True, 'LENGTH': 1, 'LOWER': '5'}]},
        {"label":"BAUGEBIETE","pattern":[{'LOWER': 'wr', 'IS_UPPER': True, 'LENGTH': 2},{'IS_DIGIT': True, 'LENGTH': 1, 'LOWER': '6'}]},
        {"label":"BAUGEBIETE","pattern":[{'LOWER': 'wr', 'IS_UPPER': True, 'LENGTH': 2},{'IS_DIGIT': True, 'LENGTH': 1, 'LOWER': '7'}]},
        {"label":"BAUGEBIETE","pattern":[{'LOWER': 'wr1', 'IS_UPPER': True, 'LENGTH': 3}]},
        {"label":"BAUGEBIETE","pattern":[{'LOWER': 'wr2', 'IS_UPPER': True, 'LENGTH': 3}]},
        {"label":"BAUGEBIETE","pattern":[{'LOWER': 'wr3', 'IS_UPPER': True, 'LENGTH': 3}]},
        {"label":"BAUGEBIETE","pattern":[{'LOWER': 'wr4', 'IS_UPPER': True, 'LENGTH': 3}]},
        {"label":"BAUGEBIETE","pattern":[{'LOWER': 'wr5', 'IS_UPPER': True, 'LENGTH': 3}]},
        {"label":"BAUGEBIETE","pattern":[{'LOWER': 'wr6', 'IS_UPPER': True, 'LENGTH': 3}]},
        {"label":"BAUGEBIETE","pattern":[{'LOWER': 'wr7', 'IS_UPPER': True, 'LENGTH': 3}]},
        {"label":"BAUGEBIETE","pattern":[{"TEXT":{"FUZZY": "allgemeines"}},{"TEXT":{"FUZZY":"wohngebiet"}}]},
        {"label":"BAUGEBIETE","pattern":[{"TEXT":{"FUZZY": "allgemeine"}},{"TEXT":{"FUZZY":"wohngebiete"}}]},
        {"label":"BAUGEBIETE","pattern":[{'IS_UPPER': True, 'LENGTH': 2, 'LOWER': 'wa'}]},
        {"label":"BAUGEBIETE","pattern": [{"TEXT": {"REGEX": "^WA($|[^0-9])"}}]},
        {"label":"BAUGEBIETE","pattern":[{'LOWER': 'wa', 'IS_UPPER': True, 'LENGTH': 2},{'IS_DIGIT': True, 'LENGTH': 1, 'LOWER': '1'}]},
        {"label":"BAUGEBIETE","pattern":[{'LOWER': 'wa', 'IS_UPPER': True, 'LENGTH': 2},{'IS_DIGIT': True, 'LENGTH': 1, 'LOWER': '2'}]},
        {"label":"BAUGEBIETE","pattern":[{'LOWER': 'wa', 'IS_UPPER': True, 'LENGTH': 2},{'IS_DIGIT': True, 'LENGTH': 1, 'LOWER': '3'}]},
        {"label":"BAUGEBIETE","pattern":[{'LOWER': 'wa', 'IS_UPPER': True, 'LENGTH': 2},{'IS_DIGIT': True, 'LENGTH': 1, 'LOWER': '4'}]},
        {"label":"BAUGEBIETE","pattern":[{'LOWER': 'wa', 'IS_UPPER': True, 'LENGTH': 2},{'IS_DIGIT': True, 'LENGTH': 1, 'LOWER': '5'}]},
        {"label":"BAUGEBIETE","pattern":[{'LOWER': 'wa', 'IS_UPPER': True, 'LENGTH': 2},{'IS_DIGIT': True, 'LENGTH': 1, 'LOWER': '6'}]},
        {"label":"BAUGEBIETE","pattern":[{'LOWER': 'wa', 'IS_UPPER': True, 'LENGTH': 2},{'IS_DIGIT': True, 'LENGTH': 1, 'LOWER': '7'}]},
        {"label":"BAUGEBIETE","pattern":[{'LOWER': 'wa1', 'IS_UPPER': True, 'LENGTH': 3}]},
        {"label":"BAUGEBIETE","pattern":[{'LOWER': 'wa2', 'IS_UPPER': True, 'LENGTH': 3}]},
        {"label":"BAUGEBIETE","pattern":[{'LOWER': 'wa3', 'IS_UPPER': True, 'LENGTH': 3}]},
        {"label":"BAUGEBIETE","pattern":[{'LOWER': 'wa4', 'IS_UPPER': True, 'LENGTH': 3}]},
        {"label":"BAUGEBIETE","pattern":[{'LOWER': 'wa5', 'IS_UPPER': True, 'LENGTH': 3}]},
        {"label":"BAUGEBIETE","pattern":[{'LOWER': 'wa6', 'IS_UPPER': True, 'LENGTH': 3}]},
        {"label":"BAUGEBIETE","pattern":[{'LOWER': 'wa7', 'IS_UPPER': True, 'LENGTH': 3}]},
        {"label":"BAUGEBIETE","pattern":[{"TEXT":{"FUZZY": "besonderes"}},{"TEXT":{"FUZZY":"wohngebiet"}}]},
        {"label":"BAUGEBIETE","pattern":[{"TEXT":{"FUZZY": "besondere"}},{"TEXT":{"FUZZY":"wohngebiete"}}]},
        {"label":"BAUGEBIETE","pattern":[{'IS_UPPER': True, 'LENGTH': 2, 'LOWER': 'wb'}]},
        {"label":"BAUGEBIETE","pattern": [{"TEXT": {"REGEX": "^WB($|[^0-9])"}}]},
        {"label":"BAUGEBIETE","pattern":[{'LOWER': 'wb', 'IS_UPPER': True, 'LENGTH': 2},{'IS_DIGIT': True, 'LENGTH': 1, 'LOWER': '1'}]},
        {"label":"BAUGEBIETE","pattern":[{'LOWER': 'wb', 'IS_UPPER': True, 'LENGTH': 2},{'IS_DIGIT': True, 'LENGTH': 1, 'LOWER': '2'}]},
        {"label":"BAUGEBIETE","pattern":[{'LOWER': 'wb', 'IS_UPPER': True, 'LENGTH': 2},{'IS_DIGIT': True, 'LENGTH': 1, 'LOWER': '3'}]},
        {"label":"BAUGEBIETE","pattern":[{'LOWER': 'wb', 'IS_UPPER': True, 'LENGTH': 2},{'IS_DIGIT': True, 'LENGTH': 1, 'LOWER': '4'}]},
        {"label":"BAUGEBIETE","pattern":[{'LOWER': 'wb', 'IS_UPPER': True, 'LENGTH': 2},{'IS_DIGIT': True, 'LENGTH': 1, 'LOWER': '5'}]},
        {"label":"BAUGEBIETE","pattern":[{'LOWER': 'wb', 'IS_UPPER': True, 'LENGTH': 2},{'IS_DIGIT': True, 'LENGTH': 1, 'LOWER': '6'}]},
        {"label":"BAUGEBIETE","pattern":[{'LOWER': 'wb', 'IS_UPPER': True, 'LENGTH': 2},{'IS_DIGIT': True, 'LENGTH': 1, 'LOWER': '7'}]},
        {"label":"BAUGEBIETE","pattern":[{'LOWER': 'wb1', 'IS_UPPER': True, 'LENGTH': 3}]},
        {"label":"BAUGEBIETE","pattern":[{'LOWER': 'wb2', 'IS_UPPER': True, 'LENGTH': 3}]},
        {"label":"BAUGEBIETE","pattern":[{'LOWER': 'wb3', 'IS_UPPER': True, 'LENGTH': 3}]},
        {"label":"BAUGEBIETE","pattern":[{'LOWER': 'wb4', 'IS_UPPER': True, 'LENGTH': 3}]},
        {"label":"BAUGEBIETE","pattern":[{'LOWER': 'wb5', 'IS_UPPER': True, 'LENGTH': 3}]},
        {"label":"BAUGEBIETE","pattern":[{'LOWER': 'wb6', 'IS_UPPER': True, 'LENGTH': 3}]},
        {"label":"BAUGEBIETE","pattern":[{'LOWER': 'wb7', 'IS_UPPER': True, 'LENGTH': 3}]},
        {"label":"BAUGEBIETE","pattern":[{"TEXT":{"FUZZY":"dorfgebiete"}}]},
        {"label":"BAUGEBIETE","pattern":[{"TEXT":{"FUZZY":"dorfgebiet"}}]},
        {"label":"BAUGEBIETE","pattern":[{'IS_UPPER': True, 'LENGTH': 2, 'LOWER': 'md'}]},
        {"label":"BAUGEBIETE","pattern": [{"TEXT": {"REGEX": "^MD($|[^0-9])"}}]},
        {"label":"BAUGEBIETE","pattern":[{'LOWER': 'md', 'IS_UPPER': True, 'LENGTH': 2},{'IS_DIGIT': True, 'LENGTH': 1, 'LOWER': '1'}]},
        {"label":"BAUGEBIETE","pattern":[{'LOWER': 'md', 'IS_UPPER': True, 'LENGTH': 2},{'IS_DIGIT': True, 'LENGTH': 1, 'LOWER': '2'}]},
        {"label":"BAUGEBIETE","pattern":[{'LOWER': 'md', 'IS_UPPER': True, 'LENGTH': 2},{'IS_DIGIT': True, 'LENGTH': 1, 'LOWER': '3'}]},
        {"label":"BAUGEBIETE","pattern":[{'LOWER': 'md', 'IS_UPPER': True, 'LENGTH': 2},{'IS_DIGIT': True, 'LENGTH': 1, 'LOWER': '4'}]},
        {"label":"BAUGEBIETE","pattern":[{'LOWER': 'md', 'IS_UPPER': True, 'LENGTH': 2},{'IS_DIGIT': True, 'LENGTH': 1, 'LOWER': '5'}]},
        {"label":"BAUGEBIETE","pattern":[{'LOWER': 'md', 'IS_UPPER': True, 'LENGTH': 2},{'IS_DIGIT': True, 'LENGTH': 1, 'LOWER': '6'}]},
        {"label":"BAUGEBIETE","pattern":[{'LOWER': 'md', 'IS_UPPER': True, 'LENGTH': 2},{'IS_DIGIT': True, 'LENGTH': 1, 'LOWER': '7'}]},
        {"label":"BAUGEBIETE","pattern":[{'LOWER': 'md1', 'IS_UPPER': True, 'LENGTH': 3}]},
        {"label":"BAUGEBIETE","pattern":[{'LOWER': 'md2', 'IS_UPPER': True, 'LENGTH': 3}]},
        {"label":"BAUGEBIETE","pattern":[{'LOWER': 'md3', 'IS_UPPER': True, 'LENGTH': 3}]},
        {"label":"BAUGEBIETE","pattern":[{'LOWER': 'md4', 'IS_UPPER': True, 'LENGTH': 3}]},
        {"label":"BAUGEBIETE","pattern":[{'LOWER': 'md5', 'IS_UPPER': True, 'LENGTH': 3}]},
        {"label":"BAUGEBIETE","pattern":[{'LOWER': 'md6', 'IS_UPPER': True, 'LENGTH': 3}]},
        {"label":"BAUGEBIETE","pattern":[{'LOWER': 'md7', 'IS_UPPER': True, 'LENGTH': 3}]},
        {"label":"BAUGEBIETE","pattern":[{"TEXT":{"FUZZY": "dörfliches"}},{"TEXT":{"FUZZY":"wohngebiet"}}]},
        {"label":"BAUGEBIETE","pattern":[{"TEXT":{"FUZZY": "dörfliche"}},{"TEXT":{"FUZZY":"wohngebiete"}}]},
        {"label":"BAUGEBIETE","pattern":[{'IS_UPPER': True, 'LENGTH': 3, 'LOWER': 'mdw'}]},
        {"label":"BAUGEBIETE","pattern": [{"TEXT": {"REGEX": "^MDW($|[^0-9])"}}]},
        {"label":"BAUGEBIETE","pattern":[{'LOWER': 'mdw', 'IS_UPPER': True, 'LENGTH': 3},{'IS_DIGIT': True, 'LENGTH': 1, 'LOWER': '1'}]},
        {"label":"BAUGEBIETE","pattern":[{'LOWER': 'mdw', 'IS_UPPER': True, 'LENGTH': 3},{'IS_DIGIT': True, 'LENGTH': 1, 'LOWER': '2'}]},
        {"label":"BAUGEBIETE","pattern":[{'LOWER': 'mdw', 'IS_UPPER': True, 'LENGTH': 3},{'IS_DIGIT': True, 'LENGTH': 1, 'LOWER': '3'}]},
        {"label":"BAUGEBIETE","pattern":[{'LOWER': 'mdw', 'IS_UPPER': True, 'LENGTH': 3},{'IS_DIGIT': True, 'LENGTH': 1, 'LOWER': '4'}]},
        {"label":"BAUGEBIETE","pattern":[{'LOWER': 'mdw', 'IS_UPPER': True, 'LENGTH': 3},{'IS_DIGIT': True, 'LENGTH': 1, 'LOWER': '5'}]},
        {"label":"BAUGEBIETE","pattern":[{'LOWER': 'mdw', 'IS_UPPER': True, 'LENGTH': 3},{'IS_DIGIT': True, 'LENGTH': 1, 'LOWER': '6'}]},
        {"label":"BAUGEBIETE","pattern":[{'LOWER': 'mdw', 'IS_UPPER': True, 'LENGTH': 3},{'IS_DIGIT': True, 'LENGTH': 1, 'LOWER': '7'}]},
        {"label":"BAUGEBIETE","pattern":[{'LOWER': 'mdw1', 'IS_UPPER': True, 'LENGTH': 4}]},
        {"label":"BAUGEBIETE","pattern":[{'LOWER': 'mdw2', 'IS_UPPER': True, 'LENGTH': 4}]},
        {"label":"BAUGEBIETE","pattern":[{'LOWER': 'mdw3', 'IS_UPPER': True, 'LENGTH': 4}]},
        {"label":"BAUGEBIETE","pattern":[{'LOWER': 'mdw4', 'IS_UPPER': True, 'LENGTH': 4}]},
        {"label":"BAUGEBIETE","pattern":[{'LOWER': 'mdw5', 'IS_UPPER': True, 'LENGTH': 4}]},
        {"label":"BAUGEBIETE","pattern":[{'LOWER': 'mdw6', 'IS_UPPER': True, 'LENGTH': 4}]},
        {"label":"BAUGEBIETE","pattern":[{'LOWER': 'mdw7', 'IS_UPPER': True, 'LENGTH': 4}]},
        {"label":"BAUGEBIETE","pattern":[{"TEXT":{"FUZZY":"mischgebiete"}}]},
        {"label":"BAUGEBIETE","pattern":[{"TEXT":{"FUZZY":"mischgebiet"}}]},
        {"label":"BAUGEBIETE","pattern":[{'IS_UPPER': True, 'LENGTH': 2, 'LOWER': 'mi'}]},
        {"label":"BAUGEBIETE","pattern": [{"TEXT": {"REGEX": "^MI($|[^0-9])"}}]},
        {"label":"BAUGEBIETE","pattern":[{'LOWER': 'mi', 'IS_UPPER': True, 'LENGTH': 2},{'IS_DIGIT': True, 'LENGTH': 1, 'LOWER': '1'}]},
        {"label":"BAUGEBIETE","pattern":[{'LOWER': 'mi', 'IS_UPPER': True, 'LENGTH': 2},{'IS_DIGIT': True, 'LENGTH': 1, 'LOWER': '2'}]},
        {"label":"BAUGEBIETE","pattern":[{'LOWER': 'mi', 'IS_UPPER': True, 'LENGTH': 2},{'IS_DIGIT': True, 'LENGTH': 1, 'LOWER': '3'}]},
        {"label":"BAUGEBIETE","pattern":[{'LOWER': 'mi', 'IS_UPPER': True, 'LENGTH': 2},{'IS_DIGIT': True, 'LENGTH': 1, 'LOWER': '4'}]},
        {"label":"BAUGEBIETE","pattern":[{'LOWER': 'mi', 'IS_UPPER': True, 'LENGTH': 2},{'IS_DIGIT': True, 'LENGTH': 1, 'LOWER': '5'}]},
        {"label":"BAUGEBIETE","pattern":[{'LOWER': 'mi', 'IS_UPPER': True, 'LENGTH': 2},{'IS_DIGIT': True, 'LENGTH': 1, 'LOWER': '6'}]},
        {"label":"BAUGEBIETE","pattern":[{'LOWER': 'mi', 'IS_UPPER': True, 'LENGTH': 2},{'IS_DIGIT': True, 'LENGTH': 1, 'LOWER': '7'}]},
        {"label":"BAUGEBIETE","pattern":[{'LOWER': 'mi1', 'IS_UPPER': True, 'LENGTH': 3}]},
        {"label":"BAUGEBIETE","pattern":[{'LOWER': 'mi2', 'IS_UPPER': True, 'LENGTH': 3}]},
        {"label":"BAUGEBIETE","pattern":[{'LOWER': 'mi3', 'IS_UPPER': True, 'LENGTH': 3}]},
        {"label":"BAUGEBIETE","pattern":[{'LOWER': 'mi4', 'IS_UPPER': True, 'LENGTH': 3}]},
        {"label":"BAUGEBIETE","pattern":[{'LOWER': 'mi5', 'IS_UPPER': True, 'LENGTH': 3}]},
        {"label":"BAUGEBIETE","pattern":[{'LOWER': 'mi6', 'IS_UPPER': True, 'LENGTH': 3}]},
        {"label":"BAUGEBIETE","pattern":[{'LOWER': 'mi7', 'IS_UPPER': True, 'LENGTH': 3}]},
        {"label":"BAUGEBIETE","pattern":[{'LOWER':"kerngebiete"}]},
        {"label":"BAUGEBIETE","pattern":[{'LOWER':"kerngebiet"}]},
        {"label":"BAUGEBIETE","pattern":[{'IS_UPPER': True, 'LENGTH': 2, 'LOWER': 'mk'}]},
        {"label":"BAUGEBIETE","pattern": [{"TEXT": {"REGEX": "^MK($|[^0-9])"}}]},
        {"label":"BAUGEBIETE","pattern":[{'LOWER': 'mk', 'IS_UPPER': True, 'LENGTH': 2},{'IS_DIGIT': True, 'LENGTH': 1, 'LOWER': '1'}]},
        {"label":"BAUGEBIETE","pattern":[{'LOWER': 'mk', 'IS_UPPER': True, 'LENGTH': 2},{'IS_DIGIT': True, 'LENGTH': 1, 'LOWER': '2'}]},
        {"label":"BAUGEBIETE","pattern":[{'LOWER': 'mk', 'IS_UPPER': True, 'LENGTH': 2},{'IS_DIGIT': True, 'LENGTH': 1, 'LOWER': '3'}]},
        {"label":"BAUGEBIETE","pattern":[{'LOWER': 'mk', 'IS_UPPER': True, 'LENGTH': 2},{'IS_DIGIT': True, 'LENGTH': 1, 'LOWER': '4'}]},
        {"label":"BAUGEBIETE","pattern":[{'LOWER': 'mk', 'IS_UPPER': True, 'LENGTH': 2},{'IS_DIGIT': True, 'LENGTH': 1, 'LOWER': '5'}]},
        {"label":"BAUGEBIETE","pattern":[{'LOWER': 'mk', 'IS_UPPER': True, 'LENGTH': 2},{'IS_DIGIT': True, 'LENGTH': 1, 'LOWER': '6'}]},
        {"label":"BAUGEBIETE","pattern":[{'LOWER': 'mk', 'IS_UPPER': True, 'LENGTH': 2},{'IS_DIGIT': True, 'LENGTH': 1, 'LOWER': '7'}]},
        {"label":"BAUGEBIETE","pattern":[{'LOWER': 'mk1', 'IS_UPPER': True, 'LENGTH': 3}]},
        {"label":"BAUGEBIETE","pattern":[{'LOWER': 'mk2', 'IS_UPPER': True, 'LENGTH': 3}]},
        {"label":"BAUGEBIETE","pattern":[{'LOWER': 'mk3', 'IS_UPPER': True, 'LENGTH': 3}]},
        {"label":"BAUGEBIETE","pattern":[{'LOWER': 'mk4', 'IS_UPPER': True, 'LENGTH': 3}]},
        {"label":"BAUGEBIETE","pattern":[{'LOWER': 'mk5', 'IS_UPPER': True, 'LENGTH': 3}]},
        {"label":"BAUGEBIETE","pattern":[{'LOWER': 'mk6', 'IS_UPPER': True, 'LENGTH': 3}]},
        {"label":"BAUGEBIETE","pattern":[{'LOWER': 'mk7', 'IS_UPPER': True, 'LENGTH': 3}]},
        {"label":"BAUGEBIETE","pattern":[{"TEXT":{"FUZZY":"urbane"}},{"TEXT":{"FUZZY":"gebiete"}}]},
        {"label":"BAUGEBIETE","pattern":[{"TEXT":{"FUZZY":"urbanes"}},{"TEXT":{"FUZZY":"gebiet"}}]},
        {"label":"BAUGEBIETE","pattern":[{'IS_UPPER': True, 'LENGTH': 2, 'LOWER': 'mu'}]},
        {"label":"BAUGEBIETE","pattern": [{"TEXT": {"REGEX": "^MU($|[^0-9])"}}]},
        {"label":"BAUGEBIETE","pattern":[{'LOWER': 'mu', 'IS_UPPER': True, 'LENGTH': 2},{'IS_DIGIT': True, 'LENGTH': 1, 'LOWER': '1'}]},
        {"label":"BAUGEBIETE","pattern":[{'LOWER': 'mu', 'IS_UPPER': True, 'LENGTH': 2},{'IS_DIGIT': True, 'LENGTH': 1, 'LOWER': '2'}]},
        {"label":"BAUGEBIETE","pattern":[{'LOWER': 'mu', 'IS_UPPER': True, 'LENGTH': 2},{'IS_DIGIT': True, 'LENGTH': 1, 'LOWER': '3'}]},
        {"label":"BAUGEBIETE","pattern":[{'LOWER': 'mu', 'IS_UPPER': True, 'LENGTH': 2},{'IS_DIGIT': True, 'LENGTH': 1, 'LOWER': '4'}]},
        {"label":"BAUGEBIETE","pattern":[{'LOWER': 'mu', 'IS_UPPER': True, 'LENGTH': 2},{'IS_DIGIT': True, 'LENGTH': 1, 'LOWER': '5'}]},
        {"label":"BAUGEBIETE","pattern":[{'LOWER': 'mu', 'IS_UPPER': True, 'LENGTH': 2},{'IS_DIGIT': True, 'LENGTH': 1, 'LOWER': '6'}]},
        {"label":"BAUGEBIETE","pattern":[{'LOWER': 'mu', 'IS_UPPER': True, 'LENGTH': 2},{'IS_DIGIT': True, 'LENGTH': 1, 'LOWER': '7'}]},
        {"label":"BAUGEBIETE","pattern":[{'LOWER': 'mu1', 'IS_UPPER': True, 'LENGTH': 3}]},
        {"label":"BAUGEBIETE","pattern":[{'LOWER': 'mu2', 'IS_UPPER': True, 'LENGTH': 3}]},
        {"label":"BAUGEBIETE","pattern":[{'LOWER': 'mu3', 'IS_UPPER': True, 'LENGTH': 3}]},
        {"label":"BAUGEBIETE","pattern":[{'LOWER': 'mu4', 'IS_UPPER': True, 'LENGTH': 3}]},
        {"label":"BAUGEBIETE","pattern":[{'LOWER': 'mu5', 'IS_UPPER': True, 'LENGTH': 3}]},
        {"label":"BAUGEBIETE","pattern":[{'LOWER': 'mu6', 'IS_UPPER': True, 'LENGTH': 3}]},
        {"label":"BAUGEBIETE","pattern":[{'LOWER': 'mu7', 'IS_UPPER': True, 'LENGTH': 3}]},
        {"label":"BAUGEBIETE","pattern":[{"TEXT":{"FUZZY":"eingeschränktes"}},{"TEXT":{"FUZZY":"gewerbegebiet"}}]},
        {"label":"BAUGEBIETE","pattern":[{'IS_UPPER': True, 'LENGTH': 3, 'LOWER': 'gee'}]},
        {"label":"BAUGEBIETE","pattern":[{"TEXT":{"FUZZY":"gewerbegebiete"}}]},
        {"label":"BAUGEBIETE","pattern":[{"TEXT":{"FUZZY":"gewerbegebiet"}}]},
        {"label":"BAUGEBIETE","pattern":[{'IS_UPPER': True, 'LENGTH': 2, 'LOWER': 'ge'}]},
        {"label":"BAUGEBIETE","pattern": [{"TEXT": {"REGEX": "^GE($|[^0-9])"}}]},
        {"label":"BAUGEBIETE","pattern":[{'LOWER': 'ge', 'IS_UPPER': True, 'LENGTH': 2},{'IS_DIGIT': True, 'LENGTH': 1, 'LOWER': '1'}]},
        {"label":"BAUGEBIETE","pattern":[{'LOWER': 'ge', 'IS_UPPER': True, 'LENGTH': 2},{'IS_DIGIT': True, 'LENGTH': 1, 'LOWER': '2'}]},
        {"label":"BAUGEBIETE","pattern":[{'LOWER': 'ge', 'IS_UPPER': True, 'LENGTH': 2},{'IS_DIGIT': True, 'LENGTH': 1, 'LOWER': '3'}]},
        {"label":"BAUGEBIETE","pattern":[{'LOWER': 'ge', 'IS_UPPER': True, 'LENGTH': 2},{'IS_DIGIT': True, 'LENGTH': 1, 'LOWER': '4'}]},
        {"label":"BAUGEBIETE","pattern":[{'LOWER': 'ge', 'IS_UPPER': True, 'LENGTH': 2},{'IS_DIGIT': True, 'LENGTH': 1, 'LOWER': '5'}]},
        {"label":"BAUGEBIETE","pattern":[{'LOWER': 'ge', 'IS_UPPER': True, 'LENGTH': 2},{'IS_DIGIT': True, 'LENGTH': 1, 'LOWER': '6'}]},
        {"label":"BAUGEBIETE","pattern":[{'LOWER': 'ge', 'IS_UPPER': True, 'LENGTH': 2},{'IS_DIGIT': True, 'LENGTH': 1, 'LOWER': '7'}]},
        {"label":"BAUGEBIETE","pattern":[{'LOWER': 'ge1', 'IS_UPPER': True, 'LENGTH': 3}]},
        {"label":"BAUGEBIETE","pattern":[{'LOWER': 'ge2', 'IS_UPPER': True, 'LENGTH': 3}]},
        {"label":"BAUGEBIETE","pattern":[{'LOWER': 'ge3', 'IS_UPPER': True, 'LENGTH': 3}]},
        {"label":"BAUGEBIETE","pattern":[{'LOWER': 'ge4', 'IS_UPPER': True, 'LENGTH': 3}]},
        {"label":"BAUGEBIETE","pattern":[{'LOWER': 'ge5', 'IS_UPPER': True, 'LENGTH': 3}]},
        {"label":"BAUGEBIETE","pattern":[{'LOWER': 'ge6', 'IS_UPPER': True, 'LENGTH': 3}]},
        {"label":"BAUGEBIETE","pattern":[{'LOWER': 'ge7', 'IS_UPPER': True, 'LENGTH': 3}]},
        {"label":"BAUGEBIETE","pattern":[{"TEXT":{"FUZZY":"industriegebiete"}}]},
        {"label":"BAUGEBIETE","pattern":[{"TEXT":{"FUZZY":"industriegebiet"}}]},
        {"label":"BAUGEBIETE","pattern":[{'IS_UPPER': True, 'LENGTH': 2, 'LOWER': 'gi'}]},
        {"label":"BAUGEBIETE","pattern": [{"TEXT": {"REGEX": "^GI($|[^0-9])"}}]},
        {"label":"BAUGEBIETE","pattern":[{'LOWER': 'gi', 'IS_UPPER': True, 'LENGTH': 2},{'IS_DIGIT': True, 'LENGTH': 1, 'LOWER': '1'}]},
        {"label":"BAUGEBIETE","pattern":[{'LOWER': 'gi', 'IS_UPPER': True, 'LENGTH': 2},{'IS_DIGIT': True, 'LENGTH': 1, 'LOWER': '2'}]},
        {"label":"BAUGEBIETE","pattern":[{'LOWER': 'gi', 'IS_UPPER': True, 'LENGTH': 2},{'IS_DIGIT': True, 'LENGTH': 1, 'LOWER': '3'}]},
        {"label":"BAUGEBIETE","pattern":[{'LOWER': 'gi', 'IS_UPPER': True, 'LENGTH': 2},{'IS_DIGIT': True, 'LENGTH': 1, 'LOWER': '4'}]},
        {"label":"BAUGEBIETE","pattern":[{'LOWER': 'gi', 'IS_UPPER': True, 'LENGTH': 2},{'IS_DIGIT': True, 'LENGTH': 1, 'LOWER': '5'}]},
        {"label":"BAUGEBIETE","pattern":[{'LOWER': 'gi', 'IS_UPPER': True, 'LENGTH': 2},{'IS_DIGIT': True, 'LENGTH': 1, 'LOWER': '6'}]},
        {"label":"BAUGEBIETE","pattern":[{'LOWER': 'gi', 'IS_UPPER': True, 'LENGTH': 2},{'IS_DIGIT': True, 'LENGTH': 1, 'LOWER': '7'}]},
        {"label":"BAUGEBIETE","pattern":[{'LOWER': 'gi1', 'IS_UPPER': True, 'LENGTH': 3}]},
        {"label":"BAUGEBIETE","pattern":[{'LOWER': 'gi2', 'IS_UPPER': True, 'LENGTH': 3}]},
        {"label":"BAUGEBIETE","pattern":[{'LOWER': 'gi3', 'IS_UPPER': True, 'LENGTH': 3}]},
        {"label":"BAUGEBIETE","pattern":[{'LOWER': 'gi4', 'IS_UPPER': True, 'LENGTH': 3}]},
        {"label":"BAUGEBIETE","pattern":[{'LOWER': 'gi5', 'IS_UPPER': True, 'LENGTH': 3}]},
        {"label":"BAUGEBIETE","pattern":[{'LOWER': 'gi6', 'IS_UPPER': True, 'LENGTH': 3}]},
        {"label":"BAUGEBIETE","pattern":[{'LOWER': 'gi7', 'IS_UPPER': True, 'LENGTH': 3}]},
        {"label":"BAUGEBIETE","pattern":[{"TEXT":{"FUZZY":"sondergebiete"}}]},
        {"label":"BAUGEBIETE","pattern":[{"TEXT":{"FUZZY":"sondergebiet"}}]},
        {"label":"BAUGEBIETE","pattern":[{'LOWER': "campingplatzgebiete"}]},
        {"label":"BAUGEBIETE","pattern":[{"LOWER": "ferienhausgebiete"}]},
        {"label":"BAUGEBIETE","pattern":[{"LOWER": "wochenendhausgebiete"}]},
        {"label":"BAUGEBIETE","pattern":[{"LOWER": "hochschulgebiete"}]},
        {"label":"BAUGEBIETE","pattern":[{"LOWER": "großflächige Handelsbetriebe"}]},
        {"label":"BAUGEBIETE","pattern":[{"LOWER": "ladengebiete"}]},
        {"label":"BAUGEBIETE","pattern":[{'IS_UPPER': True, 'LENGTH': 2, 'LOWER': 'so'}]},
        {"label":"BAUGEBIETE","pattern":[{"TEXT": {"REGEX": "^SO($|[^0-9])"}}]},
        {"label":"BAUGEBIETE","pattern":[{'LOWER': 'so', 'IS_UPPER': True, 'LENGTH': 2},{'IS_DIGIT': True, 'LENGTH': 1, 'LOWER': '1'}]},
        {"label":"BAUGEBIETE","pattern":[{'LOWER': 'so', 'IS_UPPER': True, 'LENGTH': 2},{'IS_DIGIT': True, 'LENGTH': 1, 'LOWER': '2'}]},
        {"label":"BAUGEBIETE","pattern":[{'LOWER': 'so', 'IS_UPPER': True, 'LENGTH': 2},{'IS_DIGIT': True, 'LENGTH': 1, 'LOWER': '3'}]},
        {"label":"BAUGEBIETE","pattern":[{'LOWER': 'so', 'IS_UPPER': True, 'LENGTH': 2},{'IS_DIGIT': True, 'LENGTH': 1, 'LOWER': '4'}]},
        {"label":"BAUGEBIETE","pattern":[{'LOWER': 'so', 'IS_UPPER': True, 'LENGTH': 2},{'IS_DIGIT': True, 'LENGTH': 1, 'LOWER': '5'}]},
        {"label":"BAUGEBIETE","pattern":[{'LOWER': 'so', 'IS_UPPER': True, 'LENGTH': 2},{'IS_DIGIT': True, 'LENGTH': 1, 'LOWER': '6'}]},
        {"label":"BAUGEBIETE","pattern":[{'LOWER': 'so', 'IS_UPPER': True, 'LENGTH': 2},{'IS_DIGIT': True, 'LENGTH': 1, 'LOWER': '7'}]},
        {"label":"BAUGEBIETE","pattern":[{'LOWER': 'so1', 'IS_UPPER': True, 'LENGTH': 3}]},
        {"label":"BAUGEBIETE","pattern":[{'LOWER': 'so2', 'IS_UPPER': True, 'LENGTH': 3}]},
        {"label":"BAUGEBIETE","pattern":[{'LOWER': 'so3', 'IS_UPPER': True, 'LENGTH': 3}]},
        {"label":"BAUGEBIETE","pattern":[{'LOWER': 'so4', 'IS_UPPER': True, 'LENGTH': 3}]},
        {"label":"BAUGEBIETE","pattern":[{'LOWER': 'so5', 'IS_UPPER': True, 'LENGTH': 3}]},
        {"label":"BAUGEBIETE","pattern":[{'LOWER': 'so6', 'IS_UPPER': True, 'LENGTH': 3}]},
        {"label":"BAUGEBIETE","pattern":[{'LOWER': 'so7', 'IS_UPPER': True, 'LENGTH': 3}]},
        {"label":"BAUGEBIETE","pattern":[{"TEXT":{"FUZZY":"sonstiges"}},{"TEXT":{"FUZZY":"sondergebiet"}}]},
        {"label":"MASS_DER_BAULICHEN_NUTZUNG","pattern":[{"TEXT":{"FUZZY":"bauhöhe"}}]},
        {"label":"MASS_DER_BAULICHEN_NUTZUNG","pattern":[{"TEXT":{"FUZZY":"gebäudehöhe"}}]},
        {"label":"MASS_DER_BAULICHEN_NUTZUNG","pattern":[{"TEXT":{"FUZZY":"höhe"}},{"TEXT":{"FUZZY":"der"}},{"TEXT":{"FUZZY":"baulichen"}},{"TEXT":{"FUZZY":"anlage"}}]},
        {"label":"MASS_DER_BAULICHEN_NUTZUNG","pattern":[{"TEXT":{"FUZZY":"grundflächenzahl"}}]},
        {"label":"MASS_DER_BAULICHEN_NUTZUNG","pattern":[{'LOWER': 'grz'}]},
        {"label":"MASS_DER_BAULICHEN_NUTZUNG","pattern":[{'LOWER': 'gfz'}]},
        {"label":"MASS_DER_BAULICHEN_NUTZUNG","pattern":[{'LOWER': 'vollgeschosse'}]},
        {"label":"MASS_DER_BAULICHEN_NUTZUNG","pattern":[{'LOWER': 'baumassenzahl'}]},
        {"label":"MASS_DER_BAULICHEN_NUTZUNG","pattern":[{'LOWER': 'baumasse'}]},
        {"label":"MASS_DER_BAULICHEN_NUTZUNG","pattern":[{'LOWER': 'bmz'}]},
        {"label":"MASS_DER_BAULICHEN_NUTZUNG","pattern":[{"TEXT":{"FUZZY":"traufhöhe"}}]},
        {"label":"MASS_DER_BAULICHEN_NUTZUNG","pattern":[{"TEXT":{"FUZZY":"firsthöhe"}}]},
        {"label":"MASS_DER_BAULICHEN_NUTZUNG","pattern":[{"TEXT":{"FUZZY":"zahl"}},{"TEXT":{"FUZZY":"der"}},{"TEXT":{"FUZZY":"vollgeschosse"}}]},
        {"label":"MASS_DER_BAULICHEN_NUTZUNG","pattern":[{"TEXT":{"FUZZY":"geschossflächenzahl"}}]},
        {"label":"MASS_DER_BAULICHEN_NUTZUNG","pattern":[{"TEXT":{"FUZZY":"geschoßflächenzahl"}}]},
        {"label":"BAUWEISE","pattern":[{"TEXT":{"FUZZY":"offene"}},{"TEXT":{"FUZZY":"bauweise"}}]},
        {"label":"BAUWEISE","pattern":[{"TEXT":{"FUZZY":"abweichende"}},{"TEXT":{"FUZZY":"bauweise"}}]},
        {"label":"BAUWEISE","pattern":[{"TEXT":{"FUZZY":"geschlossene"}},{"TEXT":{"FUZZY":"bauweise"}}]},
        {"label":"BAUWEISE","pattern":[{"TEXT":{"FUZZY":"besondere"}},{"TEXT":{"FUZZY":"bauweise"}}]},
        {"label":"BAUWEISE","pattern":[{"TEXT":{"FUZZY":"halboffene"}},{"TEXT":{"FUZZY":"bauweise"}}]}, 
        {"label":"BAUWEISE","pattern":[{"TEXT":{"FUZZY":"halbgeschlossene"}},{"TEXT":{"FUZZY":"bauweise"}}]}, 
        {"label":"BAUWEISE","pattern":[{"TEXT":{"FUZZY":"überbaubare"}},{"TEXT":{"FUZZY":"grundstücksfläche"}}]},
        {"label":"BAUWEISE","pattern":[{"TEXT":{"FUZZY":"nichtüberbaubare"}},{"TEXT":{"FUZZY":"grundstücksfläche"}}]},            
        {"label":"BAUWEISE","pattern":[{"TEXT":{"FUZZY":"garagengeschosse"}}]},
        {"label":"BAUWEISE","pattern":[{"TEXT":{"FUZZY":"garagengeschoße"}}]},
        {"label":"ART_DER_BAULICHEN_NUTZUNG","pattern":[{"TEXT":{"FUZZY":"nicht"}},{"TEXT":{"FUZZY":"mehr"}},{"TEXT":{"FUZZY":"als"}},{"TEXT":{"FUZZY":"2"}},{"TEXT":{"FUZZY":"Wohnungen"}}]},
        {"label":"ART_DER_BAULICHEN_NUTZUNG","pattern":[{"TEXT":{"FUZZY":"betriebe"}},{"TEXT":{"FUZZY":"des"}},{"TEXT":{"FUZZY":"beherbergungsgewerbes"}}]},
        {"label":"ART_DER_BAULICHEN_NUTZUNG","pattern":[{"TEXT":{"FUZZY":"sonstige"}},{"TEXT":{"FUZZY":"nicht"}},{"TEXT":{"FUZZY":"störende"}},{"TEXT":{"FUZZY":"gewerbebetriebe"}}]},
        {"label":"ART_DER_BAULICHEN_NUTZUNG","pattern":[{"TEXT":{"FUZZY":"anlagen"}},{"TEXT":{"FUZZY":"für"}},{"TEXT":{"FUZZY":"verwaltungen"}}]}, 
        {"label":"ART_DER_BAULICHEN_NUTZUNG","pattern":[{"TEXT":{"FUZZY":"der"}},{"TEXT":{"FUZZY":"versorgung"}},{"TEXT":{"FUZZY":"des"}},{"TEXT":{"FUZZY":"gebiets"}},{"TEXT":{"FUZZY":"dienende"}},{"TEXT":{"FUZZY":"läden"}}]},    
        {"label":"ART_DER_BAULICHEN_NUTZUNG","pattern":[{"TEXT":{"FUZZY":"anlagen"}}, {"TEXT":{"FUZZY":"für"}}, {"TEXT":{"FUZZY":"sportliche"}}, {"TEXT":{"FUZZY":"zwecke"}} ]},   
        {"label":"ART_DER_BAULICHEN_NUTZUNG","pattern":[{"TEXT":{"FUZZY":"betriebe,"}},{"TEXT":{"FUZZY":"die"}},{"TEXT":{"FUZZY":"waren"}},{"TEXT":{"FUZZY":"oder"}},{"TEXT":{"FUZZY":"Dienstleistungen"}},{"TEXT":{"FUZZY":"zur"}},{"TEXT":{"FUZZY":"Erregung"}},{"TEXT":{"FUZZY":"sexueller"}},{"TEXT":{"FUZZY":"bedürfnisse"}},{"TEXT":{"FUZZY":"oder"}},{"TEXT":{"FUZZY":"deren"}},{"TEXT":{"FUZZY":"befriedigung"}},{"TEXT":{"FUZZY":"anbieten"}}]},
        {"label":"ART_DER_BAULICHEN_NUTZUNG","pattern":[{"TEXT":{"FUZZY":"wohnungen"}},{"TEXT":{"FUZZY":"in"}},{"TEXT":{"FUZZY":"den"}},{"TEXT":{"FUZZY":"erdgeschossen"}}]},
        {"label":"ART_DER_BAULICHEN_NUTZUNG","pattern":[{"TEXT":{"FUZZY":"wohnungen"}},{"TEXT":{"FUZZY":"im"}},{"TEXT":{"FUZZY":"keller"}}]},
        {"label":"ART_DER_BAULICHEN_NUTZUNG","pattern":[{"TEXT":{"FUZZY":"wohnungen"}},{"TEXT":{"FUZZY":"in"}},{"TEXT":{"FUZZY":"den"}},{"TEXT":{"FUZZY":"obergeschoss"}}]},  
        {"label":"ART_DER_BAULICHEN_NUTZUNG","pattern":[{"TEXT":{"FUZZY":"wohnungen"}},{"TEXT":{"FUZZY":"auf"}},{"TEXT":{"FUZZY":"dem"}},{"TEXT":{"FUZZY":"dach"}}]},
        {"label":"ART_DER_BAULICHEN_NUTZUNG","pattern":[{"TEXT":{"FUZZY":"sonstige"}}, {"TEXT":{"FUZZY":"gewerbebetriebe"}}]},
        {"label":"ART_DER_BAULICHEN_NUTZUNG","pattern":[{"TEXT":{"FUZZY":"betriebe"}},{"TEXT":{"FUZZY":"mit"}},{"TEXT":{"FUZZY":"lärmemissionen"}}]}, 
        {"label":"ART_DER_BAULICHEN_NUTZUNG","pattern":[{"TEXT":{"FUZZY":"verkaufsflächen"}},{"TEXT":{"FUZZY":"für"}},{"TEXT":{"FUZZY":"schwerpunktsortimente"}}]},  
        {"label":"ART_DER_BAULICHEN_NUTZUNG","pattern":[{"TEXT":{"FUZZY":"lärmemissionen"}},{"TEXT":{"FUZZY":"durch"}},{"TEXT":{"FUZZY":"freizeitaktivitäten"}}]}, 
        {"label":"ART_DER_BAULICHEN_NUTZUNG","pattern":[{"TEXT":{"FUZZY":"vermietung"}}, {"TEXT":{"FUZZY":"von"}}, {"TEXT":{"FUZZY":"geräten"}}, {"TEXT":{"FUZZY":"fahrzeugen"}}]},    
        {"label":"ART_DER_BAULICHEN_NUTZUNG","pattern":[{"TEXT":{"FUZZY":"lagerung"}},{"TEXT":{"FUZZY":"von"}},{"TEXT":{"FUZZY":"gefährlichen"}},{"TEXT":{"FUZZY":"stoffen"}}]},  
        {"label":"ART_DER_BAULICHEN_NUTZUNG","pattern":[{"TEXT":{"FUZZY":"vermietung"}},{"TEXT":{"FUZZY":"von"}},{"TEXT":{"FUZZY":"wohnraum"}}]}, 
        {"label":"ART_DER_BAULICHEN_NUTZUNG","pattern":[{"TEXT":{"FUZZY":"vermietung"}},{"TEXT":{"FUZZY":"von"}},{"TEXT":{"FUZZY":"büroräumen"}}]}, 
        {"label":"ART_DER_BAULICHEN_NUTZUNG","pattern":[{"TEXT":{"FUZZY":"räume"}},{"TEXT":{"FUZZY":"für"}},{"TEXT":{"FUZZY":"freie"}},{"TEXT":{"FUZZY":"berufe"}}]},
        {"label":"ART_DER_BAULICHEN_NUTZUNG","pattern":[{"TEXT":{"FUZZY":"vermietung"}},{"TEXT":{"FUZZY":"von"}},{"TEXT":{"FUZZY":"lagerflächen"}}]},  
        {"label":"ART_DER_BAULICHEN_NUTZUNG","pattern":[{"TEXT":{"FUZZY":"werbung"}},{"TEXT":{"FUZZY":"oder"}},{"TEXT":{"FUZZY":"plakatierung"}}]}, 
        {"label":"ART_DER_BAULICHEN_NUTZUNG","pattern":[{"TEXT":{"FUZZY":"vermietung"}}, {"TEXT":{"FUZZY":"von"}}, {"TEXT":{"FUZZY":"werbeflächen"}}]},
        {"label":"ART_DER_BAULICHEN_NUTZUNG","pattern":[{"TEXT":{"FUZZY":"stellplätze"}},{"TEXT":{"FUZZY":"für"}},{"TEXT":{"FUZZY":"lkws"}},{"TEXT":{"FUZZY":"oder"}},{"TEXT":{"FUZZY":"schwertransporter"}}]},
        {"label":"ART_DER_BAULICHEN_NUTZUNG","pattern":[{"TEXT":{"FUZZY":"stellplätze"}},{"TEXT":{"FUZZY":"für"}},{"TEXT":{"FUZZY":"wohnwagen"}},{"TEXT":{"FUZZY":"oder"}},{"TEXT":{"FUZZY":"mobile"}},{"TEXT":{"FUZZY":"heime"}}]},
        {"label":"ART_DER_BAULICHEN_NUTZUNG","pattern":[{"TEXT":{"FUZZY":"stellplätze"}},{"TEXT":{"FUZZY":"für"}},{"TEXT":{"FUZZY":"wohnmobile"}}]},
        {"label":"ART_DER_BAULICHEN_NUTZUNG","pattern":[{"TEXT":{"FUZZY":"einrichtungen"}},{"TEXT":{"FUZZY":"zur"}},{"TEXT":{"FUZZY":"medizinischen"}},{"TEXT":{"FUZZY":"versorgung"}}]},
        {"label":"ART_DER_BAULICHEN_NUTZUNG","pattern":[{"TEXT":{"FUZZY":"militärische"}},{"TEXT":{"FUZZY":"einrichtungen"}}]},
        {"label":"ART_DER_BAULICHEN_NUTZUNG","pattern":[{"TEXT":{"FUZZY":"tankstellen"}}]},
        {"label":"ART_DER_BAULICHEN_NUTZUNG","pattern":[{"TEXT":{"FUZZY":"werbeflächen"}}]},
        {"label":"ART_DER_BAULICHEN_NUTZUNG","pattern":[{"TEXT":{"FUZZY":"werbeanlage"}}]},
        {"label":"ART_DER_BAULICHEN_NUTZUNG","pattern":[{"TEXT":{"FUZZY":"gartenbaubetriebe"}}]},
        {"label":"ART_DER_BAULICHEN_NUTZUNG","pattern":[{"TEXT":{"FUZZY":"einzelhandelsbetriebe"}}]},
        {"label":"ART_DER_BAULICHEN_NUTZUNG","pattern":[{'LOWER':"industrieanlagen"}]},
        {"label":"ART_DER_BAULICHEN_NUTZUNG","pattern":[{'LOWER':"veranstaltungsräume"}]},
        {"label":"ART_DER_BAULICHEN_NUTZUNG","pattern":[{'LOWER':"veranstaltungsraum"}]},
        {"label":"ART_DER_BAULICHEN_NUTZUNG","pattern":[{'LOWER':"kirmesplatz"}]},
        {"label":"ART_DER_BAULICHEN_NUTZUNG","pattern":[{'LOWER':"vereinsheime"}]},
        {"label":"ART_DER_BAULICHEN_NUTZUNG","pattern":[{'LOWER':"marktplatz"}]},
        {'label':'ART_DER_BAULICHEN_NUTZUNG','pattern':[{"TEXT":{"FUZZY": 'wohngebäude'}}]},
        {"label":"ART_DER_BAULICHEN_NUTZUNG","pattern":[{'LOWER':"öffentliche"}, {'LOWER':"betriebe"}]},
        {"label":"ART_DER_BAULICHEN_NUTZUNG","pattern":[{'LOWER':"öffentlicher"}, {'LOWER':"betrieb"}]},
        {"label":"ART_DER_BAULICHEN_NUTZUNG","pattern":[{'LOWER':"spielhallen"}]},
        {"label":"ART_DER_BAULICHEN_NUTZUNG","pattern":[{'LOWER':"spielhalle"}]},
        {"label":"ART_DER_BAULICHEN_NUTZUNG","pattern":[{'LOWER':"baumärkte"}]},
        {"label":"ART_DER_BAULICHEN_NUTZUNG","pattern":[{'LOWER':"baumarkt"}]},
        {"label":"ART_DER_BAULICHEN_NUTZUNG","pattern":[{'LOWER':"gartenzentren"}]},
        {"label":"ART_DER_BAULICHEN_NUTZUNG","pattern":[{'LOWER':"einzelhandel"}]},
        {"label":"ART_DER_BAULICHEN_NUTZUNG","pattern":[{'LOWER':"gartenzentrum"}]},
        {"label":"ART_DER_BAULICHEN_NUTZUNG","pattern":[{'LOWER':"sex-shops"}]},
        {"label":"ART_DER_BAULICHEN_NUTZUNG","pattern":[{'LOWER':"sex-shop"}]},
        {"label":"ART_DER_BAULICHEN_NUTZUNG","pattern":[{'LOWER':"sex-kinos"}]},
        {"label":"ART_DER_BAULICHEN_NUTZUNG","pattern":[{'LOWER':"sex-kino"}]},
        {"label":"ART_DER_BAULICHEN_NUTZUNG","pattern":[{'LOWER':"peep-shows"}]},
        {"label":"ART_DER_BAULICHEN_NUTZUNG","pattern":[{'LOWER':"bordelle"}]},
        {"label":"ART_DER_BAULICHEN_NUTZUNG","pattern":[{'LOWER':"bordellbetriebe"}]},
        {"label":"ART_DER_BAULICHEN_NUTZUNG","pattern":[{'LOWER':"laufhäuser"}]},
        {"label":"ART_DER_BAULICHEN_NUTZUNG","pattern":[{'LOWER':"freudenhäuser"}]},
        {"label":"ART_DER_BAULICHEN_NUTZUNG","pattern":[{'LOWER':"gartenlauben"}]},
        {"label":"ART_DER_BAULICHEN_NUTZUNG","pattern":[{'LOWER':"baustoffhandel"}]},
        {"label":"ART_DER_BAULICHEN_NUTZUNG","pattern":[{'LOWER':"kleingartenanlagen"}]},
        {"label":"ART_DER_BAULICHEN_NUTZUNG","pattern":[{'LOWER':"parkhäuser"}]},
        {"label":"ART_DER_BAULICHEN_NUTZUNG","pattern":[{'LOWER':"parkhäuser"}]},
        {"label":"ART_DER_BAULICHEN_NUTZUNG","pattern":[{'LOWER':"parkhaus"}]},
        {"label":"ART_DER_BAULICHEN_NUTZUNG","pattern":[{'LOWER':"sportplaetze"}]},
        {"label":"ART_DER_BAULICHEN_NUTZUNG","pattern":[{'LOWER':"sportplatz"}]},
        {"label":"ART_DER_BAULICHEN_NUTZUNG","pattern":[{'LOWER':"sportanlagen"}]},
        {"label":"ART_DER_BAULICHEN_NUTZUNG","pattern":[{'LOWER':"sportanlage"}]},
        {"label":"ART_DER_BAULICHEN_NUTZUNG","pattern":[{'LOWER':"fitnessstudios"}]},
        {"label":"ART_DER_BAULICHEN_NUTZUNG","pattern":[{'LOWER':"fitnessstudio"}]},
        {"label":"ART_DER_BAULICHEN_NUTZUNG","pattern":[{'LOWER':"sporthallen"}]},
        {"label":"ART_DER_BAULICHEN_NUTZUNG","pattern":[{'LOWER':"sportclubs"}]},
        {"label":"ART_DER_BAULICHEN_NUTZUNG","pattern":[{'LOWER':"lagerbetriebe"}]},
        {"label":"ART_DER_BAULICHEN_NUTZUNG","pattern":[{'LOWER':"geräteschuppen"}]},
        {"label":"ART_DER_BAULICHEN_NUTZUNG","pattern":[{'LOWER':"berkaufsplätze"}]},
        {"label":"ART_DER_BAULICHEN_NUTZUNG","pattern":[{'LOWER':"parkanlagen"}]},
        {"label":"ART_DER_BAULICHEN_NUTZUNG","pattern":[{'LOWER':"parkanlage"}]},
        {"label":"ART_DER_BAULICHEN_NUTZUNG","pattern":[{'LOWER':"spielplätze"}]},
        {"label":"ART_DER_BAULICHEN_NUTZUNG","pattern":[{'LOWER':"spielplatz"}]},
        {"label":"ART_DER_BAULICHEN_NUTZUNG","pattern":[{'LOWER':"lagerfläche"}]},
        {"label":"ART_DER_BAULICHEN_NUTZUNG","pattern":[{'LOWER':"lagerflächen"}]},
        {"label":"ART_DER_BAULICHEN_NUTZUNG","pattern":[{'LOWER':"kirchen"}]},
        {"label":"ART_DER_BAULICHEN_NUTZUNG","pattern":[{'LOWER':"kindergärten"}]},
        {"label":"ART_DER_BAULICHEN_NUTZUNG","pattern":[{'LOWER':"krippen"}]},
        {"label":"ART_DER_BAULICHEN_NUTZUNG","pattern":[{'LOWER':"sektkellereien"}]},
        {"label":"ART_DER_BAULICHEN_NUTZUNG","pattern":[{'LOWER':"kinderkrippen"}]},
        {"label":"ART_DER_BAULICHEN_NUTZUNG","pattern":[{'LOWER':"schulen"}]},
        {"label":"ART_DER_BAULICHEN_NUTZUNG","pattern":[{'LOWER':"schule"}]},
        {"label":"ART_DER_BAULICHEN_NUTZUNG","pattern":[{'LOWER':"tagungsstätte"}]},
        {"label":"ART_DER_BAULICHEN_NUTZUNG","pattern":[{'LOWER':"gewerbebetriebe"}]},
        {"label":"ART_DER_BAULICHEN_NUTZUNG","pattern":[{'LOWER':"gewerbebetrieb"}]},
        {"label":"ART_DER_BAULICHEN_NUTZUNG","pattern":[{'LOWER':"krankenhäuser"}]},
        {"label":"ART_DER_BAULICHEN_NUTZUNG","pattern":[{'LOWER':"kinos"}]},
        {"label":"ART_DER_BAULICHEN_NUTZUNG","pattern":[{'LOWER':"theater"}]},
        {"label":"ART_DER_BAULICHEN_NUTZUNG","pattern":[{'LOWER':"konzerthallen"}]},
        {"label":"ART_DER_BAULICHEN_NUTZUNG","pattern":[{'LOWER':"museen"}]},
        {"label":"ART_DER_BAULICHEN_NUTZUNG","pattern":[{'LOWER':"galerien"}]},
        {"label":"ART_DER_BAULICHEN_NUTZUNG","pattern":[{'LOWER':"kulturzentren"}]},
        {"label":"ART_DER_BAULICHEN_NUTZUNG","pattern":[{'LOWER':"kulturhaus"}]},
        {"label":"ART_DER_BAULICHEN_NUTZUNG","pattern":[{'LOWER':"bibliotheken"}]},
        {"label":"ART_DER_BAULICHEN_NUTZUNG","pattern":[{'LOWER':"buchhandlungen"}]},
        {"label":"ART_DER_BAULICHEN_NUTZUNG","pattern":[{'LOWER':"lagerhäuser"}]},
        {"label":"ART_DER_BAULICHEN_NUTZUNG","pattern":[{'LOWER':"lagerplätze"}]},
        {"label":"ART_DER_BAULICHEN_NUTZUNG","pattern":[{'LOWER':"rampen"}]},
        {"label":"ART_DER_BAULICHEN_NUTZUNG","pattern":[{'LOWER':"schwimmbäder"}]},
        {"label":"ART_DER_BAULICHEN_NUTZUNG","pattern":[{'LOWER':"gartenbau"}]},
        {"label":"ART_DER_BAULICHEN_NUTZUNG","pattern":[{'LOWER':"blumenläden"}]},
        {"label":"ART_DER_BAULICHEN_NUTZUNG","pattern":[{'LOWER':"bäckereien"}]},
        {"label":"ART_DER_BAULICHEN_NUTZUNG","pattern":[{'LOWER':"konditoreien"}]},
        {"label":"ART_DER_BAULICHEN_NUTZUNG","pattern":[{'LOWER':"metzgereien"}]},
        {"label":"ART_DER_BAULICHEN_NUTZUNG","pattern":[{'LOWER':"schlachter"}]},
        {"label":"ART_DER_BAULICHEN_NUTZUNG","pattern":[{'LOWER':"schlachthof"}]},
        {"label":"ART_DER_BAULICHEN_NUTZUNG","pattern":[{'LOWER':"tiefgaragen"}]},
        {"label":"ART_DER_BAULICHEN_NUTZUNG","pattern":[{'LOWER':"gemüseläden"}]},
        {"label":"ART_DER_BAULICHEN_NUTZUNG","pattern":[{'LOWER':"fleischerei"}]},
        {"label":"ART_DER_BAULICHEN_NUTZUNG","pattern":[{'LOWER':"fischläden"}]},
        {"label":"ART_DER_BAULICHEN_NUTZUNG","pattern":[{'LOWER':"käseladen"}]},
        {"label":"ART_DER_BAULICHEN_NUTZUNG","pattern":[{'LOWER':"lebensmittelmärkte"}]},
        {"label":"ART_DER_BAULICHEN_NUTZUNG","pattern":[{'LOWER':"lebensmittelgeschäfte"}]},
        {"label":"ART_DER_BAULICHEN_NUTZUNG","pattern":[{'LOWER':"lebensmittelhandel"}]},
        {"label":"ART_DER_BAULICHEN_NUTZUNG","pattern":[{'LOWER':"supermarkt"}]},
        {"label":"ART_DER_BAULICHEN_NUTZUNG","pattern":[{'LOWER':"discounter"}]},
        {"label":"ART_DER_BAULICHEN_NUTZUNG","pattern":[{'LOWER':"einkaufszentrum"}]},
        {"label":"ART_DER_BAULICHEN_NUTZUNG","pattern":[{'LOWER':"einkaufszentren"}]},
        {"label":"ART_DER_BAULICHEN_NUTZUNG","pattern":[{'LOWER':"einkaufscenter"}]},
        {"label":"ART_DER_BAULICHEN_NUTZUNG", "pattern":[{'LOWER':"discotheken"}]},
        {"label":"ART_DER_BAULICHEN_NUTZUNG","pattern":[{'LOWER':"wohnnutzung"}]},
        {"label":"ART_DER_BAULICHEN_NUTZUNG","pattern":[{'LOWER':"getränkemärkte"}]},
        {"label":"ART_DER_BAULICHEN_NUTZUNG","pattern":[{'LOWER':"getränkehandel"}]},
        {"label":"ART_DER_BAULICHEN_NUTZUNG","pattern":[{'LOWER':"getränkefachmärkte"}]},
        {"label":"ART_DER_BAULICHEN_NUTZUNG","pattern":[{'LOWER':"spirituosenhandel"}]},
        {"label":"ART_DER_BAULICHEN_NUTZUNG","pattern":[{'LOWER':"spirituosenmärkte"}]},
        {"label":"ART_DER_BAULICHEN_NUTZUNG","pattern":[{'LOWER':"spirituosenfachmärkte"}]},
        {"label":"ART_DER_BAULICHEN_NUTZUNG","pattern":[{'LOWER':"weinkeller"}]},
        {"label":"ART_DER_BAULICHEN_NUTZUNG","pattern":[{'LOWER':"weinhandel"}]},
        {"label":"ART_DER_BAULICHEN_NUTZUNG","pattern":[{'LOWER':"brauerei"}]},
        {"label":"ART_DER_BAULICHEN_NUTZUNG","pattern":[{'LOWER':"garagen"}]},
        {"label":"ART_DER_BAULICHEN_NUTZUNG","pattern":[{'LOWER':"stellplätze"}]},
        {"label":"ART_DER_BAULICHEN_NUTZUNG","pattern":[{'LOWER':"eisdielen"}]},
        {"label":"ART_DER_BAULICHEN_NUTZUNG","pattern":[{'LOWER':"gastronomie"}]},
        {"label":"ART_DER_BAULICHEN_NUTZUNG","pattern":[{'LOWER':"gaststätte"}]},
        {"label":"ART_DER_BAULICHEN_NUTZUNG","pattern":[{'LOWER':"gartenhäuser"}]},
        {"label":"ART_DER_BAULICHEN_NUTZUNG","pattern":[{'LOWER':"gartenhaus"}]},
        {"label":"ART_DER_BAULICHEN_NUTZUNG","pattern":[{'LOWER':"geräteräume"}]},
        {"label":"ART_DER_BAULICHEN_NUTZUNG","pattern":[{'LOWER':"snacksverkauf"}]},
        {"label":"ART_DER_BAULICHEN_NUTZUNG","pattern":[{'LOWER':"kleidungsgeschäft"}]},
        {"label":"ART_DER_BAULICHEN_NUTZUNG","pattern":[{'LOWER':"modegeschäft"}]},
        {"label":"ART_DER_BAULICHEN_NUTZUNG","pattern":[{'LOWER':"schuhgeschäft"}]},
        {"label":"ART_DER_BAULICHEN_NUTZUNG","pattern":[{'LOWER':"accessoiresgeschäft"}]},
        {"label":"ART_DER_BAULICHEN_NUTZUNG","pattern":[{'LOWER':"schmuckgeschäft"}]},
        {"label":"ART_DER_BAULICHEN_NUTZUNG","pattern":[{'LOWER':"spielzeuggeschäft"}]},
        {"label":"ART_DER_BAULICHEN_NUTZUNG","pattern":[{'LOWER':"sportgeschäft"}]},
        {"label":"ART_DER_BAULICHEN_NUTZUNG","pattern":[{'LOWER':"parfümerien"}]},
        {"label":"ART_DER_BAULICHEN_NUTZUNG","pattern":[{'LOWER':"kosmetikgeschäft"}]},
        {"label":"ART_DER_BAULICHEN_NUTZUNG","pattern":[{'LOWER':"haushaltswarengeschäft"}]},
        {"label":"ART_DER_BAULICHEN_NUTZUNG","pattern":[{'LOWER':"baumarktgeschäft"}]},
        {"label":"ART_DER_BAULICHEN_NUTZUNG","pattern":[{'LOWER':"blumencenter"}]},
        {"label":"ART_DER_BAULICHEN_NUTZUNG","pattern":[{'LOWER':"parkplätze"}]},
        {"label":"ART_DER_BAULICHEN_NUTZUNG","pattern":[{'LOWER':"parkplatz"}]},
        {"label":"ART_DER_BAULICHEN_NUTZUNG","pattern":[{'LOWER':"nebenanlagen"}]},
        {"label":"ART_DER_BAULICHEN_NUTZUNG","pattern":[{'LOWER':"nebenanlage"}]},
        {"label":"ART_DER_BAULICHEN_NUTZUNG","pattern":[{'LOWER':"gartencenter"}]},
        {"label":"ART_DER_BAULICHEN_NUTZUNG","pattern":[{'LOWER':"buchhandlungen"}]},
        {"label":"ART_DER_BAULICHEN_NUTZUNG","pattern":[{'LOWER':"zeitschriftengeschäft"}]},
        {'label':'ART_DER_BAULICHEN_NUTZUNG', 'pattern':[{'LOWER': 'läden'}]},
        {'label':'ART_DER_BAULICHEN_NUTZUNG', 'pattern':[{'LOWER': 'laden'}]}, 
        {"label":"ART_DER_BAULICHEN_NUTZUNG", "pattern": [{'TEXT': {'FUZZY': 'Handwerks-'}}, {'TEXT': {'FUZZY': 'und'}}, {'TEXT': {'FUZZY': 'Gewerbebetriebe'}}]},
        {"label":"ART_DER_BAULICHEN_NUTZUNG", "pattern": [{'TEXT': {'FUZZY': 'Anlagen'}}, {'TEXT': {'FUZZY': 'für'}}, {'TEXT': {'FUZZY': 'soziale,'}}, {'TEXT': {'FUZZY': 'gesundheitliche'}}, {'TEXT': {'FUZZY': 'und'}}, {'TEXT': {'FUZZY': 'sportliche'}}, {'TEXT': {'FUZZY': 'Zwecke'}}]},
        {"label":"ART_DER_BAULICHEN_NUTZUNG", "pattern": [{'TEXT': {'FUZZY': 'Anlagen'}}, {'TEXT': {'FUZZY': 'von'}}, {'TEXT': {'FUZZY': 'Gewerbebetrieben'}}]},                 
        {"label":"ART_DER_BAULICHEN_NUTZUNG", "pattern": [{'TEXT': {'FUZZY': 'Versorgung'}}, {'TEXT': {'FUZZY': 'der'}}, {'TEXT': {'FUZZY': 'Baugebiete'}}, {'TEXT': {'FUZZY': 'mit'}}, {'TEXT': {'FUZZY': 'Elektrizität'}}, {'TEXT': {'FUZZY': 'Gas'}}, {'TEXT': {'FUZZY': 'Wärme'}}, {'TEXT': {'FUZZY': 'und'}}, {'TEXT': {'FUZZY': 'Wasser'}}]},     
        {"label":"ART_DER_BAULICHEN_NUTZUNG", "pattern": [{'TEXT': {'FUZZY': 'oberhalb'}}, {'TEXT': {'FUZZY': 'eines'}}, {'TEXT': {'FUZZY': 'im'}}, {'TEXT': {'FUZZY': 'Bebauungsplan'}}, {'TEXT': {'FUZZY': 'bestimmten'}}, {'TEXT': {'FUZZY': 'Geschosses'}}, {'TEXT': {'FUZZY': 'nur'}}, {'TEXT': {'FUZZY': 'Wohnungen'}}]},
        {"label":"ART_DER_BAULICHEN_NUTZUNG", "pattern": [{'TEXT': {'FUZZY': 'Büro-'}}, {'TEXT': {'FUZZY': 'und'}}, {'TEXT': {'FUZZY': 'Verwaltungsgebäude'}}]},   
        {"label":"ART_DER_BAULICHEN_NUTZUNG", "pattern": [{'TEXT': {'FUZZY': 'Ableitung'}}, {'TEXT': {'FUZZY': 'von'}}, {'TEXT': {'FUZZY': 'Abwässern'}}]},
        {"label":"ART_DER_BAULICHEN_NUTZUNG", "pattern": [{'TEXT': {'FUZZY': 'nicht'}}, {'TEXT': {'FUZZY': 'störende'}}, {'TEXT': {'FUZZY': 'Gewerbe'}}]},
        {"label":"ART_DER_BAULICHEN_NUTZUNG", "pattern": [{'TEXT': {'FUZZY': 'Anlagen'}}, {'TEXT': {'FUZZY': 'für'}}, {'TEXT': {'FUZZY': 'soziale,'}}, {'TEXT': {'FUZZY': 'gesundheitliche'}}, {'TEXT': {'FUZZY': 'und'}}, {'TEXT': {'FUZZY': 'sportliche'}}, {'TEXT': {'FUZZY': 'Zwecke'}}]},
        {'label':'ART_DER_BAULICHEN_NUTZUNG', 'pattern':[{'TEXT': {'FUZZY': 'Schank-'}}, {'TEXT': {'FUZZY': 'und'}}, {'TEXT': {'FUZZY': 'Speisewirtschaften'}}]},
        {"label":"ART_DER_BAULICHEN_NUTZUNG", "pattern": [{'TEXT': {'FUZZY': 'Büro-'}}, {'TEXT': {'FUZZY': 'Dienstleistungs-'}}, {'TEXT': {'FUZZY': 'und'}}, {'TEXT': {'FUZZY': 'Verwaltungsgebäuden'}}]},
        {"label":"ART_DER_BAULICHEN_NUTZUNG", "pattern": [{'TEXT': {'FUZZY': 'Anlagen'}}, {'TEXT': {'FUZZY': 'des'}}, {'TEXT': {'FUZZY': 'Post-'}}, {'TEXT': {'FUZZY': 'und'}}, {'TEXT': {'FUZZY': 'Fernmeldewesens'}}]},
        {'label':'ART_DER_BAULICHEN_NUTZUNG,', 'pattern': [{'TEXT': {'FUZZY': 'Kleinsiedlungen'}}, {'TEXT': {'FUZZY': 'einschließlich'}}, {'TEXT': {'FUZZY': 'Wohngebäude'}}, {'TEXT': {'FUZZY': 'mit'}}, {'TEXT': {'FUZZY': 'entsprechenden'}}, {'TEXT': {'FUZZY': 'Nutzgärten'}}, {'TEXT': {'FUZZY': ','}}, {'TEXT': {'FUZZY': 'landwirtschaftliche'}}, {'TEXT': {'FUZZY': 'Nebenerwerbsstellen'}}, {'TEXT': {'FUZZY': 'und'}}, {'TEXT': {'FUZZY': 'Gartenbaubetriebe'}}]},
        {'label':'ART_DER_BAULICHEN_NUTZUNG', 'pattern': [{'TEXT': {'FUZZY': 'die'}}, {'TEXT': {'FUZZY': 'der'}}, {'TEXT': {'FUZZY': 'Versorgung'}}, {'TEXT': {'FUZZY': 'des'}}, {'TEXT': {'FUZZY': 'Gebiets'}}, {'TEXT': {'FUZZY': 'dienenden'}}, {'TEXT': {'FUZZY': 'Läden'}}, {'TEXT': {'FUZZY': ','}}, {'TEXT': {'FUZZY': 'Schank-'}}, {'TEXT': {'FUZZY': 'und'}}, {'TEXT': {'FUZZY': 'Speisewirtschaften'}}, {'TEXT': {'FUZZY': 'sowie'}}, {'TEXT': {'FUZZY': 'nicht'}}, {'TEXT': {'FUZZY': 'störenden'}}, {'TEXT': {'FUZZY': 'Handwerksbetriebe'}} ]},
        {'label':'ART_DER_BAULICHEN_NUTZUNG', 'pattern': [{'TEXT': {'FUZZY': 'nicht'}}, {'TEXT': {'FUZZY': 'störende'}}, {'TEXT': {'FUZZY': 'Handwerksbetriebe'}}]},
        {'label':'ART_DER_BAULICHEN_NUTZUNG', 'pattern': [{'TEXT': {'FUZZY': 'sonstige'}}, {'TEXT': {'FUZZY': 'Wohngebäude'}}, {'TEXT': {'FUZZY': 'mit'}}, {'TEXT': {'FUZZY': 'nicht'}}, {'TEXT': {'FUZZY': 'mehr'}}, {'TEXT': {'FUZZY': 'als'}}, {'TEXT': {'FUZZY': 'zwei'}}, {'TEXT': {'FUZZY': 'Wohnungen'}}]},
        {'label':'ART_DER_BAULICHEN_NUTZUNG', 'pattern': [{'TEXT': {'FUZZY': 'Anlagen'}}, {'TEXT': {'FUZZY': 'für'}}, {'TEXT': {'FUZZY': 'kirchliche'}}, {'TEXT': {'FUZZY': ','}}, {'TEXT': {'FUZZY': 'kulturelle'}}, {'TEXT': {'FUZZY': ','}}, {'TEXT': {'FUZZY': 'soziale'}}, {'TEXT': {'FUZZY': ','}}, {'TEXT': {'FUZZY': 'gesundheitliche'}}, {'TEXT': {'FUZZY': 'und'}}, {'TEXT': {'FUZZY': 'sportliche'}}, {'TEXT': {'FUZZY': 'Zwecke'}}]},
        {'label':'ART_DER_BAULICHEN_NUTZUNG', 'pattern': [{'TEXT': {'FUZZY': 'nicht'}}, {'TEXT': {'FUZZY': 'störende'}}, {'TEXT': {'FUZZY': 'Gewerbebetriebe'}}]},
        {'label':'ART_DER_BAULICHEN_NUTZUNG', 'pattern': [{'TEXT': {'FUZZY': 'Anlagen'}}, {'TEXT': {'FUZZY': 'zur'}}, {'TEXT': {'FUZZY': 'Kinderbetreuung,'}}, {'TEXT': {'FUZZY': 'die'}}, {'TEXT': {'FUZZY': 'den'}}, {'TEXT': {'FUZZY': 'Bedürfnissen'}}, {'TEXT': {'FUZZY': 'der'}}, {'TEXT': {'FUZZY': 'Bewohner'}}, {'TEXT': {'FUZZY': 'des'}}, {'TEXT': {'FUZZY': 'Gebiets'}}, {'TEXT': {'FUZZY': 'dienen'}}]},
        {'label':'ART_DER_BAULICHEN_NUTZUNG', 'pattern': [{'TEXT': {'FUZZY': 'Läden'}}, {'TEXT': {'FUZZY': 'und'}}, {'TEXT': {'FUZZY': 'nicht'}}, {'TEXT': {'FUZZY': 'störende'}}, {'TEXT': {'FUZZY': 'Handwerksbetriebe,'}}, {'TEXT': {'FUZZY': 'die'}}, {'TEXT': {'FUZZY': 'zur'}}, {'TEXT': {'FUZZY': 'Deckung'}}, {'TEXT': {'FUZZY': 'des'}}, {'TEXT': {'FUZZY': 'täglichen'}}, {'TEXT': {'FUZZY': 'Bedarfs'}}, {'TEXT': {'FUZZY': 'für'}}, {'TEXT': {'FUZZY': 'die'}}, {'TEXT': {'FUZZY': 'Bewohner'}}, {'TEXT': {'FUZZY': 'des'}}, {'TEXT': {'FUZZY': 'Gebiets'}}, {'TEXT': {'FUZZY': 'dienen,'}}, {'TEXT': {'FUZZY': 'sowie'}}, {'TEXT': {'FUZZY': 'kleine'}}, {'TEXT': {'FUZZY': 'Betriebe'}}, {'TEXT': {'FUZZY': 'des'}}, {'TEXT': {'FUZZY': 'Beherbergungsgewerbes'}}]},
        {'label':'ART_DER_BAULICHEN_NUTZUNG', 'pattern': [{'TEXT': {'FUZZY': 'sonstige'}}, {'TEXT': {'FUZZY': 'Anlagen'}}, {'TEXT': {'FUZZY': 'für'}}, {'TEXT': {'FUZZY': 'soziale'}}, {'TEXT': {'FUZZY': 'Zwecke'}}, {'TEXT': {'FUZZY': 'sowie'}}, {'TEXT': {'FUZZY': 'den'}}, {'TEXT': {'FUZZY': 'Bedürfnissen'}}, {'TEXT': {'FUZZY': 'der'}}, {'TEXT': {'FUZZY': 'Bewohner'}}, {'TEXT': {'FUZZY': 'des'}}, {'TEXT': {'FUZZY': 'Gebiets'}}, {'TEXT': {'FUZZY': 'dienende'}}, {'TEXT': {'FUZZY': 'Anlagen'}}, {'TEXT': {'FUZZY': 'für'}}, {'TEXT': {'FUZZY': 'kirchliche,'}}, {'TEXT': {'FUZZY': 'kulturelle,'}}, {'TEXT': {'FUZZY': 'gesundheitliche'}}, {'TEXT': {'FUZZY': 'und'}}, {'TEXT': {'FUZZY': 'sportliche'}}, {'TEXT': {'FUZZY': 'Zwecke'}}]},
        {'label':'ART_DER_BAULICHEN_NUTZUNG', 'pattern': [{'TEXT': {'FUZZY': 'Betriebe'}}, {'TEXT': {'FUZZY': 'des'}}, {'TEXT': {'FUZZY': 'Beherbergungsgewerbes'}}]},
        {'label':'ART_DER_BAULICHEN_NUTZUNG', 'pattern': [{'TEXT': {'FUZZY': 'sonstige'}}, {'TEXT': {'FUZZY': 'nicht'}}, {'TEXT': {'FUZZY': 'störende'}}, {'TEXT': {'FUZZY': 'Gewerbebetriebe'}}]}, 
        {'label':'ART_DER_BAULICHEN_NUTZUNG', 'pattern': [{'TEXT': {'FUZZY': 'zentrale'}}, {'TEXT': {'FUZZY': 'einrichtungen'}}, {'TEXT': {'FUZZY': 'für'}}, {'TEXT': {'FUZZY': 'öffentlicher'}}, {'TEXT': {'FUZZY': 'und'}}, {'TEXT': {'FUZZY': 'privater'}}, {'TEXT': {'FUZZY': 'werwaltungen'}}]}, 
        {'label':'ART_DER_BAULICHEN_NUTZUNG', 'pattern': [{'TEXT': {'FUZZY': 'Ställe'}}, {'TEXT': {'FUZZY': 'für'}}, {'TEXT': {'FUZZY': 'Kleintierhaltung'}}, {'TEXT': {'FUZZY': 'als'}}, {'TEXT': {'FUZZY': 'Zubehör'}}, {'TEXT': {'FUZZY': 'zu'}}, {'TEXT': {'FUZZY': 'Kleinsiedlungen'}}, {'TEXT': {'FUZZY': 'und'}}, {'TEXT': {'FUZZY': 'landwirtschaftlichen'}}, {'TEXT': {'FUZZY': 'Nebenerwerbsstellen'}}]},
        {'label':'ART_DER_BAULICHEN_NUTZUNG', 'pattern': [{'TEXT': {'FUZZY': 'einzelhandelsbetriebe'}}]},
        {'label':'ART_DER_BAULICHEN_NUTZUNG', 'pattern': [{'TEXT': {'FUZZY': 'sonstige'}}, {'TEXT': {'FUZZY': 'nicht'}}, {'TEXT': {'FUZZY': 'störende'}}, {'TEXT': {'FUZZY': 'Handwerksbetriebe'}}]},
        {'label':'ART_DER_BAULICHEN_NUTZUNG', 'pattern': [{'TEXT': {'FUZZY': 'sonstige'}}, {'TEXT': {'FUZZY': 'nicht'}}, {'TEXT': {'FUZZY': 'störende'}}, {'TEXT': {'FUZZY': 'Gewerbebetriebe'}}]},
        {'label':'ART_DER_BAULICHEN_NUTZUNG', 'pattern': [{'TEXT': {'FUZZY': 'nicht'}}, {'TEXT': {'FUZZY': 'gewerbliche'}}, {'TEXT': {'FUZZY': 'Einrichtungen'}}, {'TEXT': {'FUZZY': 'und'}}, {'TEXT': {'FUZZY': 'Anlagen'}}, {'TEXT': {'FUZZY': 'für'}}, {'TEXT': {'FUZZY': 'die'}}, {'TEXT': {'FUZZY': 'Tierhaltung'}}]},
        {'label':'ART_DER_BAULICHEN_NUTZUNG', 'pattern': [{'TEXT': {'FUZZY': 'Läden,'}}, {'TEXT': {'FUZZY': 'Betriebe'}}, {'TEXT': {'FUZZY': 'des'}}, {'TEXT': {'FUZZY': 'Beherbergungsgewerbes,'}}, {'TEXT': {'FUZZY': 'Schank-'}}, {'TEXT': {'FUZZY': 'und'}}, {'TEXT': {'FUZZY': 'Speisewirtschaften'}}]},
        {'label':'ART_DER_BAULICHEN_NUTZUNG', 'pattern': [{'TEXT': {'FUZZY': 'sonstige'}}, {'TEXT': {'FUZZY': 'Gewerbebetriebe'}}]},
        {'label':'ART_DER_BAULICHEN_NUTZUNG', 'pattern': [{'TEXT': {'FUZZY': 'Geschäfts-'}}, {'TEXT': {'FUZZY': 'und'}}, {'TEXT': {'FUZZY': 'Bürogebäude'}}]},
        {'label':'ART_DER_BAULICHEN_NUTZUNG', 'pattern': [{'TEXT': {'FUZZY': 'Anlagen'}}, {'TEXT': {'FUZZY': 'für'}}, {'TEXT': {'FUZZY': 'zentrale'}}, {'TEXT': {'FUZZY': 'Einrichtungen'}}, {'TEXT': {'FUZZY': 'der'}}, {'TEXT': {'FUZZY': 'Verwaltung'}}]},
        {'label':'ART_DER_BAULICHEN_NUTZUNG', 'pattern': [{'TEXT': {'FUZZY': 'vergnügungsstätten'}}]},
        {'label':'ART_DER_BAULICHEN_NUTZUNG', 'pattern': [{'TEXT': {'FUZZY': 'oberhalb'}}, {'TEXT': {'FUZZY': 'eines'}}, {'TEXT': {'FUZZY': 'im'}}, {'TEXT': {'FUZZY': 'Bebauungsplan'}}, {'TEXT': {'FUZZY': 'bestimmten'}}, {'TEXT': {'FUZZY': 'Geschosses'}}, {'TEXT': {'FUZZY': 'nur'}}, {'TEXT': {'FUZZY': 'Wohnungen'}}, {'TEXT': {'FUZZY': 'zulässig'}}, {'TEXT': {'FUZZY': 'sind'}}]},
        {'label':'ART_DER_BAULICHEN_NUTZUNG', 'pattern': [{'TEXT': {'FUZZY': 'in'}}, {'TEXT': {'FUZZY': 'Gebäuden'}}, {'TEXT': {'FUZZY': 'ein'}}, {'TEXT': {'FUZZY': 'im'}}, {'TEXT': {'FUZZY': 'Bebauungsplan'}}, {'TEXT': {'FUZZY': 'bestimmter'}}, {'TEXT': {'FUZZY': 'Anteil'}}, {'TEXT': {'FUZZY': 'der'}}, {'TEXT': {'FUZZY': 'zulässigen'}}, {'TEXT': {'FUZZY': 'Geschossfläche'}}, {'TEXT': {'FUZZY': 'oder'}}, {'TEXT': {'FUZZY': 'eine'}}, {'TEXT': {'FUZZY': 'bestimmte'}}, {'TEXT': {'FUZZY': 'Größe'}}, {'TEXT': {'FUZZY': 'der'}}, {'TEXT': {'FUZZY': 'Geschossfläche'}}, {'TEXT': {'FUZZY': 'für'}}, {'TEXT': {'FUZZY': 'Wohnungen'}}, {'TEXT': {'FUZZY': 'zu'}}, {'TEXT': {'FUZZY': 'verwenden'}}, {'TEXT': {'FUZZY': 'ist'}}]},
        {'label':'ART_DER_BAULICHEN_NUTZUNG', 'pattern': [{'TEXT': {'FUZZY': 'Wirtschaftsstellen'}}, {'TEXT': {'FUZZY': 'land-'}}, {'TEXT': {'FUZZY': 'und'}}, {'TEXT': {'FUZZY': 'forstwirtschaftlicher'}}, {'TEXT': {'FUZZY': 'Betriebe'}}, {'TEXT': {'FUZZY': 'und'}}, {'TEXT': {'FUZZY': 'die'}}, {'TEXT': {'FUZZY': 'dazugehörigen'}}, {'TEXT': {'FUZZY': 'Wohnungen'}}, {'TEXT': {'FUZZY': 'und'}}, {'TEXT': {'FUZZY': 'Wohngebäude'}}]},
        {'label':'ART_DER_BAULICHEN_NUTZUNG', 'pattern': [{'TEXT': {'FUZZY': 'Kleinsiedlungen'}}, {'TEXT': {'FUZZY': 'einschließlich'}}, {'TEXT': {'FUZZY': 'Wohngebäude'}}, {'TEXT': {'FUZZY': 'mit'}}, {'TEXT': {'FUZZY': 'entsprechenden'}}, {'TEXT': {'FUZZY': 'Nutzgärten'}}, {'TEXT': {'FUZZY': 'und'}}, {'TEXT': {'FUZZY': 'landwirtschaftliche'}}, {'TEXT': {'FUZZY': 'Nebenerwerbsstellen'}}]},
        {'label':'ART_DER_BAULICHEN_NUTZUNG', 'pattern': [{'TEXT': {'FUZZY': 'sonstige'}}, {'TEXT': {'FUZZY': 'wohngebäude'}}]},
        {'label':'ART_DER_BAULICHEN_NUTZUNG', 'pattern': [{'TEXT': {'FUZZY': 'Wirtschaftsstellen'}}, {'TEXT': {'FUZZY': 'land-'}}, {'TEXT': {'FUZZY': 'und'}}, {'TEXT': {'FUZZY': 'forstwirtschaftlicher'}}, {'TEXT': {'FUZZY': 'Betriebe'}}]},
        {'label':'ART_DER_BAULICHEN_NUTZUNG', 'pattern': [{'TEXT': {'FUZZY': 'läden'}}, {'TEXT': {'FUZZY': 'für'}}, {'TEXT': {'FUZZY': 'den'}}, {'TEXT': {'FUZZY': 'täglichen'}}, {'TEXT': {'FUZZY': 'bedarf'}}]},
        {'label':'ART_DER_BAULICHEN_NUTZUNG', 'pattern': [{'TEXT': {'FUZZY': 'Betriebe'}}, {'TEXT': {'FUZZY': 'zur'}}, {'TEXT': {'FUZZY': 'Be-'}}, {'TEXT': {'FUZZY': 'und'}}, {'TEXT': {'FUZZY': 'Verarbeitung'}}, {'TEXT': {'FUZZY': 'und'}}, {'TEXT': {'FUZZY': 'Sammlung'}}, {'TEXT': {'FUZZY': 'land-'}}, {'TEXT': {'FUZZY': 'und'}}, {'TEXT': {'FUZZY': 'forstwirtschaftlicher'}}, {'TEXT': {'FUZZY': 'Erzeugnisse'}}]},
        {'label':'ART_DER_BAULICHEN_NUTZUNG', 'pattern': [{'TEXT': {'FUZZY': 'Einzelhandelsbetriebe,'}}, {'TEXT': {'FUZZY': 'Schank-'}}, {'TEXT': {'FUZZY': 'und'}}, {'TEXT': {'FUZZY': 'Speisewirtschaften'}}, {'TEXT': {'FUZZY': 'sowie'}}, {'TEXT': {'FUZZY': 'Betriebe'}}, {'TEXT': {'FUZZY': 'des'}}, {'TEXT': {'FUZZY': 'Beherbergungsgewerbes'}}]},
        {'label':'ART_DER_BAULICHEN_NUTZUNG', 'pattern': [{'TEXT': {'FUZZY': 'Anlagen'}}, {'TEXT': {'FUZZY': 'für'}}, {'TEXT': {'FUZZY': 'örtliche'}}, {'TEXT': {'FUZZY': 'Verwaltungen'}}, {'TEXT': {'FUZZY': 'sowie'}}, {'TEXT': {'FUZZY': 'für'}}, {'TEXT': {'FUZZY': 'kirchliche,'}}, {'TEXT': {'FUZZY': 'kulturelle,'}}, {'TEXT': {'FUZZY': 'soziale,'}}, {'TEXT': {'FUZZY': 'gesundheitliche'}}, {'TEXT': {'FUZZY': 'und'}}, {'TEXT': {'FUZZY': 'sportliche'}}, {'TEXT': {'FUZZY': 'Zwecke'}}]},
        {'label':'ART_DER_BAULICHEN_NUTZUNG', 'pattern': [{'TEXT': {'FUZZY': 'Anlagen'}}, {'TEXT': {'FUZZY': 'für'}}, {'TEXT': {'FUZZY': 'Verwaltungen'}}, {'TEXT': {'FUZZY': 'sowie'}}, {'TEXT': {'FUZZY': 'für'}}, {'TEXT': {'FUZZY': 'kirchliche,'}}, {'TEXT': {'FUZZY': 'kulturelle,'}}, {'TEXT': {'FUZZY': 'soziale,'}}, {'TEXT': {'FUZZY': 'gesundheitliche'}}, {'TEXT': {'FUZZY': 'und'}}, {'TEXT': {'FUZZY': 'sportliche'}}, {'TEXT': {'FUZZY': 'Zwecke'}}]},
        {'label':'ART_DER_BAULICHEN_NUTZUNG', 'pattern': [{'TEXT': {'FUZZY': 'im'}}, {'TEXT': {'FUZZY': 'Erdgeschoss'}}, {'TEXT': {'FUZZY': 'an'}}, {'TEXT': {'FUZZY': 'der'}}, {'TEXT': {'FUZZY': 'Straßenseite'}}, {'TEXT': {'FUZZY': 'eine'}}, {'TEXT': {'FUZZY': 'Wohnnutzung'}}, {'TEXT': {'FUZZY': 'nicht'}}, {'TEXT': {'FUZZY': 'oder'}}, {'TEXT': {'FUZZY': 'nur'}}, {'TEXT': {'FUZZY': 'ausnahmsweise'}}, {'TEXT': {'FUZZY': 'zulässig'}}, {'TEXT': {'FUZZY': 'ist'}}]},
        {'label':'ART_DER_BAULICHEN_NUTZUNG', 'pattern': [{'TEXT': {'FUZZY': 'oberhalb'}}, {'TEXT': {'FUZZY': 'eines'}}, {'TEXT': {'FUZZY': 'im'}}, {'TEXT': {'FUZZY': 'Bebauungsplan'}}, {'TEXT': {'FUZZY': 'bestimmten'}}, {'TEXT': {'FUZZY': 'Geschosses'}}, {'TEXT': {'FUZZY': 'nur'}}, {'TEXT': {'FUZZY': 'Wohnungen'}}, {'TEXT': {'FUZZY': 'zulässig'}}, {'TEXT': {'FUZZY': 'sind'}}]},
        {'label':'ART_DER_BAULICHEN_NUTZUNG', 'pattern': [{'TEXT': {'FUZZY': 'ein'}}, {'TEXT': {'FUZZY': 'im'}}, {'TEXT': {'FUZZY': 'Bebauungsplan'}}, {'TEXT': {'FUZZY': 'bestimmter'}}, {'TEXT': {'FUZZY': 'Anteil'}}, {'TEXT': {'FUZZY': 'der'}}, {'TEXT': {'FUZZY': 'zulässigen'}}, {'TEXT': {'FUZZY': 'Geschossfläche'}}, {'TEXT': {'FUZZY': 'oder'}}, {'TEXT': {'FUZZY': 'eine'}}, {'TEXT': {'FUZZY': 'im'}}, {'TEXT': {'FUZZY': 'Bebauungsplan'}}, {'TEXT': {'FUZZY': 'bestimmte'}}, {'TEXT': {'FUZZY': 'Größe'}}, {'TEXT': {'FUZZY': 'der'}}, {'TEXT': {'FUZZY': 'Geschossfläche'}}, {'TEXT': {'FUZZY': 'für'}}, {'TEXT': {'FUZZY': 'Wohnungen'}}, {'TEXT': {'FUZZY': 'zu'}}, {'TEXT': {'FUZZY': 'verwenden'}}, {'TEXT': {'FUZZY': 'ist,'}}, {'TEXT': {'FUZZY': 'oder'}}]},
        {'label':'ART_DER_BAULICHEN_NUTZUNG', 'pattern': [{'TEXT': {'FUZZY': 'ein'}}, {'TEXT': {'FUZZY': 'im'}}, {'TEXT': {'FUZZY': 'Bebauungsplan'}}, {'TEXT': {'FUZZY': 'bestimmter'}}, {'TEXT': {'FUZZY': 'Anteil'}}, {'TEXT': {'FUZZY': 'der'}}, {'TEXT': {'FUZZY': 'zulässigen'}}, {'TEXT': {'FUZZY': 'Geschossfläche'}}, {'TEXT': {'FUZZY': 'oder'}}, {'TEXT': {'FUZZY': 'eine'}}, {'TEXT': {'FUZZY': 'im'}}, {'TEXT': {'FUZZY': 'Bebauungsplan'}}, {'TEXT': {'FUZZY': 'bestimmte'}}, {'TEXT': {'FUZZY': 'Größe'}}, {'TEXT': {'FUZZY': 'der'}}, {'TEXT': {'FUZZY': 'Geschossfläche'}}, {'TEXT': {'FUZZY': 'für'}}, {'TEXT': {'FUZZY': 'gewerbliche'}}, {'TEXT': {'FUZZY': 'Nutzungen'}}, {'TEXT': {'FUZZY': 'zu'}}, {'TEXT': {'FUZZY': 'verwenden'}}, {'TEXT': {'FUZZY': 'ist'}}]},
        {'label':'ART_DER_BAULICHEN_NUTZUNG', 'pattern': [{'TEXT': {'FUZZY': 'Geschäfts-'}}, {'TEXT': {'FUZZY': ','}}, {'TEXT': {'FUZZY': 'Büro-'}}, {'TEXT': {'FUZZY': 'und'}}, {'TEXT': {'FUZZY': 'Verwaltungsgebäude'}}]},
        {'label':'ART_DER_BAULICHEN_NUTZUNG', 'pattern': [{'TEXT': {'FUZZY': 'Büro-'}}, {'TEXT': {'FUZZY': ','}}, {'TEXT': {'FUZZY': 'Geschäfts-'}}, {'TEXT': {'FUZZY': 'und'}}, {'TEXT': {'FUZZY': 'Verwaltungsgebäude'}}]},
        {'label':'ART_DER_BAULICHEN_NUTZUNG', 'pattern': [{'TEXT': {'FUZZY': 'Einzelhandelsbetriebe,'}}, {'TEXT': {'FUZZY': 'Schank-'}}, {'TEXT': {'FUZZY': 'und'}}, {'TEXT': {'FUZZY': 'Speisewirtschaften,'}}, {'TEXT': {'FUZZY': 'Betriebe'}}, {'TEXT': {'FUZZY': 'des'}}, {'TEXT': {'FUZZY': 'Beherbergungsgewerbes'}}, {'TEXT': {'FUZZY': 'und'}}, {'TEXT': {'FUZZY': 'Vergnügungsstätten'}}]},
        {'label':'ART_DER_BAULICHEN_NUTZUNG', 'pattern': [{'TEXT': {'FUZZY': 'sonstige'}}, {'TEXT': {'FUZZY': 'nicht'}}, {'TEXT': {'FUZZY': 'wesentlich'}}, {'TEXT': {'FUZZY': 'störende'}}, {'TEXT': {'FUZZY': 'Gewerbebetriebe'}}]},
        {'label':'ART_DER_BAULICHEN_NUTZUNG', 'pattern': [{'TEXT': {'FUZZY': 'Tankstellen'}}, {'TEXT': {'FUZZY': 'im'}}, {'TEXT': {'FUZZY': 'Zusammenhang'}}, {'TEXT': {'FUZZY': 'mit'}}, {'TEXT': {'FUZZY': 'Parkhäusern'}}, {'TEXT': {'FUZZY': 'und'}}, {'TEXT': {'FUZZY': 'Großgaragen'}}]},
        {'label':'ART_DER_BAULICHEN_NUTZUNG', 'pattern': [{'TEXT': {'FUZZY': 'Wohnungen'}}, {'TEXT': {'FUZZY': 'für'}}, {'TEXT': {'FUZZY': 'Aufsichts-'}}, {'TEXT': {'FUZZY': 'und'}}, {'TEXT': {'FUZZY': 'Bereitschaftspersonen'}}, {'TEXT': {'FUZZY': 'sowie'}}, {'TEXT': {'FUZZY': 'für'}}, {'TEXT': {'FUZZY': 'Betriebsinhaber'}}, {'TEXT': {'FUZZY': 'und'}}, {'TEXT': {'FUZZY': 'Betriebsleiter'}}]},
        {'label':'ART_DER_BAULICHEN_NUTZUNG', 'pattern': [{'TEXT': {'FUZZY': 'Wohnungen'}}, {'TEXT': {'FUZZY': 'für'}}, {'TEXT': {'FUZZY': 'Aufsichts-'}}, {'TEXT': {'FUZZY': 'und'}}, {'TEXT': {'FUZZY': 'Bereitschaftspersonen'}}]},
        {'label':'ART_DER_BAULICHEN_NUTZUNG', 'pattern': [{'TEXT': {'FUZZY': 'Betriebe'}}, {'TEXT': {'FUZZY': 'des'}}, {'TEXT': {'FUZZY': 'produzierenden'}}, {'TEXT': {'FUZZY': 'Gewerbes'}}]},
        {'label':'ART_DER_BAULICHEN_NUTZUNG', 'pattern': [{'TEXT': {'FUZZY': 'sonstige'}}, {'TEXT': {'FUZZY': 'Wohnungen'}}, {'TEXT': {'FUZZY': 'nach'}}, {'TEXT': {'FUZZY': 'Maßgabe'}}, {'TEXT': {'FUZZY': 'von'}}, {'TEXT': {'FUZZY': 'Festsetzungen'}}, {'TEXT': {'FUZZY': 'des'}}, {'TEXT': {'FUZZY': 'Bebauungsplans'}}]},
        {'label':'ART_DER_BAULICHEN_NUTZUNG', 'pattern': [{'TEXT': {'FUZZY': 'Tankstellen,'}}, {'TEXT': {'FUZZY': 'die'}}, {'TEXT': {'FUZZY': 'nicht'}}, {'TEXT': {'FUZZY': 'unter'}}, {'TEXT': {'FUZZY': 'Absatz'}}, {'TEXT': {'FUZZY': '2'}}, {'TEXT': {'FUZZY': 'Nummer'}}, {'TEXT': {'FUZZY': '5'}}, {'TEXT': {'FUZZY': 'fallen'}}]},
        {'label':'ART_DER_BAULICHEN_NUTZUNG', 'pattern': [{'TEXT': {'FUZZY': 'Wohnungen,'}}, {'TEXT': {'FUZZY': 'die'}}, {'TEXT': {'FUZZY': 'nicht'}}, {'TEXT': {'FUZZY': 'unter'}}, {'TEXT': {'FUZZY': 'Absatz'}}, {'TEXT': {'FUZZY': '2'}}, {'TEXT': {'FUZZY': 'Nummer'}}, {'TEXT': {'FUZZY': '6'}}, {'TEXT': {'FUZZY': 'und'}}, {'TEXT': {'FUZZY': '7'}}, {'TEXT': {'FUZZY': 'fallen'}}]},
        {'label':'ART_DER_BAULICHEN_NUTZUNG', 'pattern': [{'TEXT': {'FUZZY': 'oberhalb'}}, {'TEXT': {'FUZZY': 'eines'}}, {'TEXT': {'FUZZY': 'im'}}, {'TEXT': {'FUZZY': 'Bebauungsplan'}}, {'TEXT': {'FUZZY': 'bestimmten'}}, {'TEXT': {'FUZZY': 'Geschosses'}}, {'TEXT': {'FUZZY': 'nur'}}, {'TEXT': {'FUZZY': 'Wohnungen'}}, {'TEXT': {'FUZZY': 'zulässig'}}, {'TEXT': {'FUZZY': 'sind'}}, {'TEXT': {'FUZZY': 'oder'}}]},
        {'label':'ART_DER_BAULICHEN_NUTZUNG', 'pattern': [{'TEXT': {'FUZZY': 'in'}}, {'TEXT': {'FUZZY': 'Gebäuden'}}, {'TEXT': {'FUZZY': 'ein'}}, {'TEXT': {'FUZZY': 'im'}}, {'TEXT': {'FUZZY': 'Bebauungsplan'}}, {'TEXT': {'FUZZY': 'bestimmter'}}, {'TEXT': {'FUZZY': 'Anteil'}}, {'TEXT': {'FUZZY': 'der'}}, {'TEXT': {'FUZZY': 'zulässigen'}}, {'TEXT': {'FUZZY': 'Geschossfläche'}}, {'TEXT': {'FUZZY': 'oder'}}, {'TEXT': {'FUZZY': 'eine'}}, {'TEXT': {'FUZZY': 'bestimmte'}}, {'TEXT': {'FUZZY': 'Größe'}}, {'TEXT': {'FUZZY': 'der'}}, {'TEXT': {'FUZZY': 'Geschossfläche'}}, {'TEXT': {'FUZZY': 'für'}}, {'TEXT': {'FUZZY': 'Wohnungen'}}, {'TEXT': {'FUZZY': 'zu'}}, {'TEXT': {'FUZZY': 'verwenden'}}, {'TEXT': {'FUZZY': 'ist'}}]},
        {'label':'ART_DER_BAULICHEN_NUTZUNG', 'pattern': [{'TEXT': {'FUZZY': 'Gewerbebetriebe'}}, {'TEXT': {'FUZZY': 'aller'}}, {'TEXT': {'FUZZY': 'Art'}}, {'TEXT': {'FUZZY': 'einschließlich'}}, {'TEXT': {'FUZZY': 'Anlagen'}}, {'TEXT': {'FUZZY': 'zur'}}, {'TEXT': {'FUZZY': 'Erzeugung'}}, {'TEXT': {'FUZZY': 'von'}}, {'TEXT': {'FUZZY': 'Strom'}}, {'TEXT': {'FUZZY': 'oder'}}, {'TEXT': {'FUZZY': 'Wärme'}}, {'TEXT': {'FUZZY': 'aus'}}, {'TEXT': {'FUZZY': 'solarer'}}, {'TEXT': {'FUZZY': 'Strahlungsenergie'}}, {'TEXT': {'FUZZY': 'oder'}}, {'TEXT': {'FUZZY': 'Windenergie,'}}, {'TEXT': {'FUZZY': 'Lagerhäuser,'}}, {'TEXT': {'FUZZY': 'Lagerplätze'}}, {'TEXT': {'FUZZY': 'und'}}, {'TEXT': {'FUZZY': 'öffentliche'}}, {'TEXT': {'FUZZY': 'Betriebe'}}]},
        {'label':'ART_DER_BAULICHEN_NUTZUNG', 'pattern': [{'TEXT': {'FUZZY': 'Anlagen'}}, {'TEXT': {'FUZZY': 'für'}}, {'TEXT': {'FUZZY': 'sportliche'}}, {'TEXT': {'FUZZY': 'Zwecke'}}]},
        {'label':'ART_DER_BAULICHEN_NUTZUNG', 'pattern': [{'TEXT': {'FUZZY': 'Geschäfts-'}}, {'TEXT': {'FUZZY': 'und'}}, {'TEXT': {'FUZZY': 'Büronutzungen'}}, {'TEXT': {'FUZZY': 'Zwecke'}}]},
        {'label':'ART_DER_BAULICHEN_NUTZUNG', 'pattern': [{'TEXT': {'FUZZY': 'Wohngebäude'}}, {'TEXT': {'FUZZY': 'mit'}}, {'TEXT': {'FUZZY': 'höchstens'}}, {'TEXT': {'FUZZY': 'zwei'}}, {'TEXT': {'FUZZY': 'Wohnungen'}}]},
        {'label':'ART_DER_BAULICHEN_NUTZUNG', 'pattern': [{'TEXT': {'FUZZY': 'großflächige'}}, {'TEXT': {'FUZZY': 'Einzelhandelsbetriebe'}}]},
        {'label':'ART_DER_BAULICHEN_NUTZUNG', 'pattern': [{'TEXT': {'FUZZY': 'großflächige'}}, {'TEXT': {'FUZZY': 'Einzelhandel'}}]}, 
        {'label':'ART_DER_BAULICHEN_NUTZUNG', 'pattern': [{'TEXT': {'FUZZY': 'Versorgung'}}, {'TEXT': {'FUZZY': 'mit'}}, {'TEXT': {'FUZZY': 'Elektrizität'}}]},
        {'label':'ART_DER_BAULICHEN_NUTZUNG', 'pattern': [{'TEXT': {'FUZZY': 'großflächige'}}, {'TEXT': {'FUZZY': 'Einzelhandel'}}, {'TEXT': {'FUZZY': 'mit'}}, {'TEXT': {'FUZZY': 'nicht'}}, {'TEXT': {'FUZZY': 'zentrenrelevanten'}}, {'TEXT': {'FUZZY': 'Sortiment'}}]},
        {'label':'ART_DER_BAULICHEN_NUTZUNG', 'pattern': [{'TEXT': {'FUZZY': 'großflächige'}}, {'TEXT': {'FUZZY': 'Einzelhandel'}}, {'TEXT': {'FUZZY': 'mit'}}, {'TEXT': {'FUZZY': 'zentrenrelevanten'}}, {'TEXT': {'FUZZY': 'Sortiment'}}]},
        {'label':'ART_DER_BAULICHEN_NUTZUNG', 'pattern': [{'TEXT': {'FUZZY': 'Wohnungen'}}, {'TEXT': {'FUZZY': 'für'}}, {'TEXT': {'FUZZY': 'Aufsichts-'}}, {'TEXT': {'FUZZY': 'und'}}, {'TEXT': {'FUZZY': 'Bereitschaftspersonen'}}, {'TEXT': {'FUZZY': 'sowie'}}, {'TEXT': {'FUZZY': 'für'}}, {'TEXT': {'FUZZY': 'Betriebsinhaber'}}, {'TEXT': {'FUZZY': 'und'}}, {'TEXT': {'FUZZY': 'Betriebsleiter'}}]},
        {'label':'ART_DER_BAULICHEN_NUTZUNG', 'pattern': [{'TEXT': {'FUZZY': 'Läden'}}, {'TEXT': {'FUZZY': 'mit'}}, {'TEXT': {'FUZZY': 'nahversorgungsrelevanten'}}, {'TEXT': {'FUZZY': 'Sortimenten'}}]},
        {'label':'ART_DER_BAULICHEN_NUTZUNG', 'pattern': [{'TEXT': {'FUZZY': 'nicht'}}, {'TEXT': {'FUZZY': 'mehr'}}, {'TEXT': {'FUZZY': 'als'}}, {'TEXT': {'FUZZY': 'zwei'}}, {'TEXT': {'FUZZY': 'Wohnungen'}}, {'TEXT': {'FUZZY': 'haben'}}]}
    ]
    ruler.add_patterns(patterns_baugebiete)
    doc = nlp(doc)
    return doc

# %%
def adjust_indices(entities, changes_map):
    new_entities = []
    for start, end, label in entities:
        for index, change_amount in changes_map.items():
            if start >= index:
                start += change_amount
                end += change_amount
        new_entities.append((start, end, label))
    return new_entities

def modify_string(char_start_index, char_ending_index, text):
    operation = random.randint(0, 9)
    
    if operation < 3:
        # Delete a character
        text = text[:char_ending_index] + text[char_ending_index+1:]
        char_ending_index -= 1
    elif operation < 6:
        # Insert a character
        char_to_insert = random.choice(string.ascii_lowercase)  # Replace with the desired characters to insert
        text = text[:char_ending_index] + char_to_insert + text[char_ending_index:]
        char_ending_index += 1
    elif operation < 9:
        # Swap two characters
        char_index_1 = random.randint(char_start_index, char_ending_index-1)
        char_index_2 = random.randint(char_start_index, char_ending_index-1)
        text_list = list(text)
        text_list[char_index_1], text_list[char_index_2] = text_list[char_index_2], text_list[char_index_1]
        text = ''.join(text_list)
    else:
        # Do nothing
        return text
    
    return text


def introduce_error(text):
    words = text.split(" ")
    change_map = {}
    rnd = random.random()
    index = random.randint(0, len(words) - 1)  # Choose a random word to apply error to

    if rnd < 0.3:  # Replace the word with a random word
        new_word = ''.join(random.choices(string.ascii_uppercase + string.ascii_lowercase + 'äüöß', k=len(words[index])))
        # Compute index change
        index_change = len(new_word) - len(words[index])
        words[index] = new_word
        change_map[index] = index_change

    elif rnd < 0.6:  # Delete the word
        index_change = -len(words[index])
        del words[index]
        change_map[index] = index_change

    elif rnd < 0.9:  # Swap random characters within the word
        word = list(words[index])
        if len(word) > 1:
            swap_i, swap_j = random.sample(range(0, len(word)), 2)
            word[swap_i], word[swap_j] = word[swap_j], word[swap_i]
            words[index] = "".join(word)
        # No change in index for char swap

    return " ".join(words), change_map



# Load necessary Python libraries
import random
import string
import os
import spacy
from transformers import BertTokenizer

# Load the spaCy model for tokenization
nlp = spacy.blank("de")

max_tokens = 256  # Maximum sequence length
training_data = {'classes': ['ART_DER_BAULICHEN_NUTZUNG', "MASS_DER_BAULICHEN_NUTZUNG", "BAUWEISE", "BAUGEBIETE"],
                 'annotations': []}

def tokenize_and_split(text):
    doc = nlp(text)
    tokens = []
    for token in doc:
        tokens.append(token.text)
    return tokens

tokenizer = BertTokenizer.from_pretrained('bert-base-german-cased')

for file in os.listdir("dev2"):
    if file.endswith(".txt"):
        filename = file
        with open("dev2/" + file) as f:
            file_content = f.read()
            file_content = file_content.replace('\n', ' ')
            
            # Tokenize and split the content
            tokens = tokenize_and_split(file_content)
            
            # Split into chunks of maximum 512 tokens
            for i in range(0, len(tokens), max_tokens):
                chunk_tokens = tokens[i:i + max_tokens]
                chunk_text = ' '.join(chunk_tokens)
                
                # Ensure chunk length is within model's max sequence length
                if len(chunk_tokens) <= max_tokens and len(tokenizer.tokenize(chunk_text)) <= 512:
                    # Perform entity annotation on the chunk
                    doc_ents = pre_regex_annotation(chunk_text)
                    entities = []
                    for ents in doc_ents.ents:
                        start = ents.start_char
                        end = ents.end_char
                        label = ents.label_.upper()
                        entities.append((start, end, label))
                        
                    
                    temp_dict = {}
                    temp_dict['text'] = chunk_text
                    temp_dict['entities'] = new_entities
                    
                    training_data['annotations'].append(temp_dict)
                else:
                    print("Chunk length exceeds maximum sequence length.")
                    print(len(tokenizer.tokenize(chunk_text)))
# Out:
# Chunk length exceeds maximum sequence length.
# 597
# Chunk length exceeds maximum sequence length.
# 958
# Chunk length exceeds maximum sequence length.
# 598
# Chunk length exceeds maximum sequence length.
# 1163
# Chunk length exceeds maximum sequence length.
# 1096
# Chunk length exceeds maximum sequence length.
# 614
# Chunk length exceeds maximum sequence length.
# 658
# Chunk length exceeds maximum sequence length.
# 621
# Chunk length exceeds maximum sequence length.
# 738
# Chunk length exceeds maximum sequence length.
# 685
# Chunk length exceeds maximum sequence length.
# 741
# Chunk length exceeds maximum sequence length.
# 696
# Chunk length exceeds maximum sequence length.
# 784
# Chunk length exceeds maximum sequence length.
# 799
# Chunk length exceeds maximum sequence length.
# 750
# Chunk length exceeds maximum sequence length.
# 819
# Chunk length exceeds maximum sequence length.
# 726
# Chunk length exceeds maximum sequence length.
# 710
# ...

# %%
with open("data/ner_test.txt") as f:
    text = f.read()
    print(docs)
# Out:
# /Users/abinashselvarajah/anaconda3/envs/bachelorarbeit/lib/python3.8/site-packages/spacy/util.py:887: UserWarning: [W095] Model 'de_pipeline' (0.0.0) was trained with spaCy v3.5 and may not be 100% compatible with the current version (3.5.3). If you see errors or degraded performance, download a newer compatible model or retrain your custom model with the current spaCy version. For more details and available updates, run: python -m spacy validate
#   warnings.warn(warn_msg)
# (Einzelhandelsbetrieb,)

# %%
print(training_data['annotations'][9])
# Out:
# {'text': '-1Y-   des Bundesbahngeländes beansprucht wird , soll eine Wartung der im Weg vorhandenen Sielleitung ermöglichen und zusätzlich eine zweite Fußwegverbindung zwischen dem Wohngebiet östlich der Pfitznerstraße und dem geplanten Freizeitzentrum mit Sportanla- gen westlich des schaffen .   Die Erschließung der Park-and-Ride-Anlage erfolgt über die Pfitznerstraße . Die Sibeliusstraße endet künftig westlich des Parkhauses.in einer Kehre , die gegenüber der öffentlich ausge- legten Fassung des Bebauungsplans geringfügig verändert wurde . Als Ersatz für entfallende öffentliche Parkplätze ist in der Sibeliusstraße eine Parkbucht festgesetzt ‚ worden .   Im mittleren und nördlichen Planbereich wurde dem Bestand ent- sprechend reines Wohngebiet mit 16-geschossiger Bebauung in ge- schlossener Bauweise festgesetzt .   Die Flächen der Bundesbahn sind entsprechend dem Bestand als oberirdische Bahnanlagen dargestellt .   IV   Das Plangebiet ist etwa 31. 200 m ® groß . Hiervon werden für S
# ...

# %%
import os
import spacy
import random
import string
import re
# Load the spaCy model for tokenization
nlp = spacy.blank("de")

max_tokens = 256  # Maximum sequence length
training_data = {'classes': ['ART_DER_BAULICHEN_NUTZUNG', "MASS_DER_BAULICHEN_NUTZUNG", "BAUWEISE", "BAUGEBIETE"], # List of entity classes
                 'annotations': []}

import re

def trim_entity_spans(data):
    invalid_span_tokens = re.compile(r'\s')
    cleaned_data = []

    for item in data:
        entities = item['entities']
        valid_entities = []

        for start, end, label in entities:
            valid_start = start
            valid_end = end

            while valid_start < len(item['text']) and invalid_span_tokens.match(item['text'][valid_start]):
                valid_start += 1

            while valid_end > 1 and invalid_span_tokens.match(item['text'][valid_end - 1]):
                valid_end -= 1

            valid_entities.append([valid_start, valid_end, label])

        cleaned_data.append({'text': item['text'], 'entities': valid_entities})

    return cleaned_data


def modify_string(char_start_index, char_ending_index, text):
    if (char_ending_index - char_start_index) < 6:
        return text, char_start_index, char_ending_index
    operation = random.randint(0, 9)
    if operation < 5:
        # Insert a character
        char_to_insert = random.choice(string.ascii_lowercase)  # Replace with the desired characters to insert
        text = text[:char_ending_index] + char_to_insert + text[char_ending_index:]
        char_ending_index += 1
    else:
        # Do nothing
        return text, char_start_index, char_ending_index
    return text, char_start_index, char_ending_index


def tokenize_and_split(text):
    doc = nlp(text)
    tokens = []
    for token in doc:
        tokens.append(token.text)
    return tokens

from transformers import BertTokenizer
tokenizer = BertTokenizer.from_pretrained('bert-base-german-cased')


for file in os.listdir("dev"):
    if file.endswith(".txt"):
        filename = file
        with open("dev/" + file) as f:
            file_content = f.read()
            file_content = file_content.replace('\n', ' ')
            
            # Tokenize and split the content
            tokens = tokenize_and_split(file_content)
            
            # Split into chunks of maximum 512 tokens
            for i in range(0, len(tokens), max_tokens):
                chunk_tokens = tokens[i:i + max_tokens]
                chunk_text = ' '.join(chunk_tokens)
                
                # Ensure chunk length is within model's max sequence length and wordpiece tokenization's max sequence length
                if len(chunk_tokens) <= max_tokens and len(tokenizer.tokenize(chunk_text)) <= 512:
                    temp_dict = {}
                    temp_dict['entities'] = []
                    
                    # Perform entity annotation on the chunk
                    doc_ents = pre_regex_annotation(chunk_text)
                    for ents in doc_ents.ents:
                        start = ents.start_char
                        end = ents.end_char
                        label = ents.label_.upper()
                        temp_dict['entities'].append((start, end, label))
                    
                    temp_dict['text'] = chunk_text
                    training_data['annotations'].append(temp_dict)
                else:
                    print("Chunk length exceeds maximum sequence length.")
                    print(len(tokenizer.tokenize(chunk_text)))
# Out:
# Chunk length exceeds maximum sequence length.
# 958
# Chunk length exceeds maximum sequence length.
# 598
# Chunk length exceeds maximum sequence length.
# 614
# Chunk length exceeds maximum sequence length.
# 658
# Chunk length exceeds maximum sequence length.
# 738
# Chunk length exceeds maximum sequence length.
# 685
# Chunk length exceeds maximum sequence length.
# 741
# Chunk length exceeds maximum sequence length.
# 696
# Chunk length exceeds maximum sequence length.
# 784
# Chunk length exceeds maximum sequence length.
# 799
# Chunk length exceeds maximum sequence length.
# 750
# Chunk length exceeds maximum sequence length.
# 819
# Chunk length exceeds maximum sequence length.
# 784
# Chunk length exceeds maximum sequence length.
# 736
# Chunk length exceeds maximum sequence length.
# 824
# Chunk length exceeds maximum sequence length.
# 995
# Chunk length exceeds maximum sequence length.
# 952
# Chunk length exceeds maximum sequence length.
# 519
# ...

# %%
for i in range(0, len(training_data)):
    print(training_data['annotations'][i])
# Out:
# {'entities': [(65, 75, 'BAUGEBIETE'), (106, 116, 'BAUGEBIETE'), (1037, 1048, 'BAUGEBIETE'), (1621, 1631, 'BAUGEBIETE')], 'text': 'Begründung zum Bebauungsplan Jenfeld 25 ( Elfsaal )   gruppen im Plangebiet nicht vor . Jedoch gehört das Plangebiet zum Lebensraum von mindestens 4 Fledermaus- und 29 Vogelarten . Die Umsetzung des Bebauungsplans erfordert den Abbruch von Gebäuden und das Fällen von altem Baumbestand , damit ist ein Konflikt mit den sogenannten Zugriffsverboten ( Tötungsverbot , Störungsverbot , Verbot der Beeinträchtigung von Lebensstätten ) des $ 44 Absatz 1 des BNatSchG ver- bunden . Der Konflikt kann durch die Einhaltung bestimmter Bauzeitenregelungen und durch die Sicherstellung vorgezogener Ausgleichsmaßnahmen vermindert und vermie- den werden , siehe Abschnitt 4.15.2 „ Fledermaus- und Vogelschutz “ .   3.3.6 Übergeordnete Programm- und Entwicklungspläne   3.4   Das Räumliche Leitbild der Behörde für Stadtentwicklung und Umwelt liegt im Entwurf ( Stand 2007 ) vor : 
# ...

# %%
print(training_data['annotations'][7])
# Out:
# {'entities': [(101, 112, 'BAUGEBIETE'), (774, 784, 'BAUGEBIETE'), (829, 841, 'ART_DER_BAULICHEN_NUTZUNG'), (1599, 1608, 'BAUGEBIETE')], 'text': 'Es hat eine Höhe von etwa 50 m über OK Gelän- de , der Sockel ist eingeschossig . Im Übrigen ist das Plangebietc oberirdisch unbebaut . Das benachbarte Burmah-Haus besitzt 14 Geschosse und hat eine Höhe von ebenfalls etwa 50 m über OK Gelände .   Das Burmah-Haus und das Finnland-Haus verfügen jeweils über Tiefgaragen . Beide Tiefga- ragen grenzen aneinander , sind aber baulich getrennt . Die Zufahrten liegen unmittelbar ne- beneinander . Die Tiefgarage des Finnland-Hauses verfügt über zwei Untergeschosse , sie wurde gleichzeitig als Bunker errichtet . Der Bunker wird für Zivilschutzzwecke nicht mehr be- nötigt und wurde zwischenzeitlich entwidmet .   3.3.3 Außenanlagen   Abgesehen von den in den Geltungsbereich einbezogenen Flächen des Gustav-Mahler- Parks ist das Planiebget vollständig versiegelt bzw. unterbaut . Die Oberflächepn der beiden
# ...

# %%
import os
import shutil
dir_a = 'directory_80'
dir_b = 'valid_pdf'
dir_c = 'new_valid'
files_in_a = [f for f in os.listdir(dir_a) if f.endswith('.txt')]
files_in_b = [f for f in os.listdir(dir_b) if f.endswith('.txt')]
files_only_in_a = set(files_in_a) - set(files_in_b)
for f in files_only_in_a:
    shutil.move(os.path.join(dir_a, f), dir_c)

# %%
import os

# %%
import os
import shutil

source_dir = "dev_data"
dir_20 = "Dir_20"
dir_80 = "Dir_80"

# Create target directories if they don't exist
os.makedirs(dir_20, exist_ok=True)
os.makedirs(dir_80, exist_ok=True)

total_items = len(os.listdir(source_dir))
num_items_20 = int(0.2 * total_items)

items = os.listdir(source_dir)
for idx, item in enumerate(items):
    src_path = os.path.join(source_dir, item)
    if idx < num_items_20:
        dst_path = os.path.join(dir_20, item)
    else:
        dst_path = os.path.join(dir_80, item)
    shutil.move(src_path, dst_path)  # Use shutil.copy for copying instead of moving

# %%
def dir_pdf_txt_conversion(input_path,output_path):
    # Laufvariable für die Bildbenennung
    i = 0
    # Pfad zu PDF angeben
    for file in os.listdir(input_path):
        # Bool-Wert, ob viele Seiten in PDF vorliegen oder nicht
        txt_name = file.split("/")[-1].split(".")[0]
        many_images = False
        if file.endswith(".pdf"):
            tmp_path = os.path.join(input_path, file)
            # PDF in jpg konvertieren                                                   BITTE ÜBERPRÜFEN
            try:
                images = convert_from_path(tmp_path,300, poppler_path='/opt/homebrew/Cellar/poppler/23.06.0/bin')
            except:
                images = convert_from_path(tmp_path,200, poppler_path='/opt/homebrew/Cellar/poppler/21.08.0/bin')
            # pdf zu jpg konvertieren
            if(len(images) == 1):
                images[0].save(absoluter_pfad_image + '/page'+ str(i) +'.jpg', 'JPEG')
            elif(len(images) >= 2):
                # viele Seiten liegen vor (aeltere Dokumente)
                many_images = True
                for j in range(0,len(images)):
                    # Bilder werden in einem gesonderten Ordner "many_images" gespeichert
                    images[j].save('/Users/abinashselvarajah/Desktop/Bachelorarbeit/Code/images/many_images/page'+ str(j) +'.jpg', 'JPEG')
            else:
                raise Exception("Keine Seiten")

            if(many_images == False):
                # Pfad zu jpg-Bild angeben
                image = cv2.imread('images/page'+ str(i) +'.jpg')
                gray = cv2.cvtColor(image, cv2.COLOR_BGR2GRAY)
                # Pfad zu Tesseract.exe angeben (MacOS)                                 BITTE ÜBERPRÜFEN
                pytesseract.pytesseract.tesseract_cmd = r'/Users/abinashselvarajah/anaconda3/envs/bachelorarbeit/bin/tesseract'
                # Texterkennung aus jpg-Bild, Sprache: Deutsch
                result = pytesseract.image_to_string(gray, lang='deu', config='--psm 1')
                with open(output_path+'/'+txt_name+'.txt', 'w') as f:
                    #result = txt_preprocessing(result)
                    f.write(result)
                    f.close()
            elif(many_images == True):
                for k in range(0,len(images)):
                    # Pfad zu jpg-Bild angeben
                    image = cv2.imread('images/many_images/page'+ str(k) +'.jpg')
                    gray = cv2.cvtColor(image, cv2.COLOR_BGR2GRAY)
                    # Pfad zu Tesseract.exe angeben                                     BITTE ÜBERPRÜFEN
                    pytesseract.pytesseract.tesseract_cmd = r'/Users/abinashselvarajah/anaconda3/envs/bachelorarbeit/bin/tesseract'
                    # Texterkennung aus jpg-Bild, Sprache: Deutsch
                    result = pytesseract.image_to_string(gray, lang='deu', config='--psm 1')
                    with open(output_path+'/many_txts/page_'+ str(k)+ '.txt', 'w') as f:
                        #result = txt_preprocessing(result)
                        f.write(result)
                        f.close()


                # Löschen der jpg-Bilder
                for m in range(0,len(images)):
                    os.remove(absoluter_pfad_image+'/many_images/page'+ str(m) +'.jpg')

                # Fetch filenames with pattern 'page_*.txt' from directory 'many_txts'
                filenames = glob.glob(os.path.join(output_path, 'many_txts', 'page_*.txt'))

                # sort filenames by number that comes after 'page_' in their names
                filenames.sort(key=lambda x: int(os.path.basename(x).split('_')[1].split('.')[0]))

                # Merge the text files
                with open(output_path+'/'+txt_name+'.txt', 'w') as outfile:
                    for filename in filenames:
                        with open(filename, 'r') as infile:
                            outfile.write(infile.read())

                # Löschen der txt-Dateien
                for m in range(0,len(images)):
                    os.remove(output_path+'/many_txts/page_'+ str(m)+ '.txt')
                i += 1

# %%
os.listdir('tra_data')
for file in os.listdir('tra_data'):
    if file.endswith('.txt'):
        with open('tra_data/'+file, 'r') as f:
            text = f.read()   
            if(len(pre_regex_annotation(text).ents)>8):
                shutil.move('tra_data/'+file, 'dev_data')
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[80], line 6
#       4 with open('tra_data/'+file, 'r') as f:
#       5     text = f.read()
# ----> 6     if(len(pre_regex_annotation(text).ents)>8):
#       7         shutil.move('tra_data/'+file, 'dev_data')
#
# Cell In[1], line 11, in pre_regex_annotation(doc)
#      10 def pre_regex_annotation(doc):
# ---> 11     nlp = spacy.blank("de")
#      12     ruler = nlp.add_pipe("entity_ruler", config={"overwrite_ents": True})
#      13     patterns_baugebiete = [
#      14         {"label":"BAUGEBIETE","pattern":[{"TEXT":{"FUZZY":"kleinsiedlungsgebiet"}}]},
#      15         {"label":"BAUGEBIETE","pattern":[{"TEXT":{"FUZZY":"kleinsiedlungsgebiete"}}]},
#    (...)
# ...

# %%
# !python -m spacy init config config.cfg --lang de --pipeline ner --optimize accuracy --hardware gpu
# Out:
# Usage: python -m spacy init config [OPTIONS] OUTPUT_FILE
# Try 'python -m spacy init config --help' for help.
#
# Error: No such option: --hardware

# %%
nlp = spacy.blank("de") # load a new spacy model
doc_bin = DocBin() # create a DocBin object
for training_example  in tqdm(training_data['annotations']): 
    text = training_example['text']
    labels = training_example['entities']
    doc = nlp.make_doc(text) 
    ents = []
    for start, end, label in labels:
        span = doc.char_span(start, end, label=label, alignment_mode="contract")
        if span is None:
            print("Skipping entity")
        else:
            ents.append(span)
    filtered_ents = filter_spans(ents)
    doc.ents = filtered_ents 
    doc_bin.add(doc)

doc_bin.to_disk("new_small_high_info_validating.spacy") # save the docbin object
# Out:
# ...
# 100%|██████████| 19606/19606 [00:14<00:00, 1342.44it/s]
